# %% [markdown]
# # MBA FIAP Inteligência Artificial & Machine Learning
#
# ## Visão Computacional: Análise de Imagens Médicas
#
# ## 1. Introdução
#
# As tecnologias de imagens médicas estão cada vez mais integradas aos sitemas de visão computacional, incluindo as imagens de raio-x.
#
# Modelos de equipamentos modernos geram imagens digitais deste tipo de exame, proporcionando análises mais completas e menos _ad-hoc_, com isso algumas pré-análises podem ser realizadas por aplicações baseadas em inteligência artificial para confirmar ou sugerir diagnósticos ao profissional responsável pelo exame.
#
# No campo dos diagósticos por raios-x, a pnenumonia é uma das enfermidades onde seu uso é um dos mais aplicados para determinar o curso de tratamento.
#
# <p align="center">
#     <img src="imagens/NORMAL2-IM-1422-0001.jpeg">
# </p>
#
# ## 2. Instruções
#
# Este projeto final tem como objetivo explorar os conhecimentos adquiridos nas aulas práticas.
#
# Por meio de uma trilha guiada, iremos constuir um modelo que seja capaz de classificar imagens de raio-x para determinar se a determinada pessoa está com alguma condição que necessita maiores cuidados.
#
# De acordo com as imagens disponíveis para o treinamento e validação, será de critério do grupo selecionar as quantidades ideais ou até mesmo pré-processar as imagens para obter o melhor resultado, nos principais indicadores de performance, como precisão, sensibilidade e pontuação F1.
#
# Este projeto poderá ser feita por grupos de até 4 pessoas.
# Caso este projeto seja substitutivo, deverá ser realizado por apenas uma pessoa.
#
# | Nome dos Integrantes     | RM            | Turma |
# | :----------------------- | :------------- | :-----: |
# | Integrante 1             | RM 12345      | `1IA` |
# | Integrante 2             | RM 12345      | `1IA` |
# | Integrante 3             | RM 12345      | `1IA` |
# | Integrante 4             | RM 12345      | `1IA` |
#
# Por ser um projeto guiado, fique atento quando houver as marcações **Implementação** indica que é necessário realizar alguma implementação em Python no bloco a seguir onde há a inscrição ```##IMPLEMENTAR``` e **Resposta** indica que é esperado uma resposta objetiva relacionado a algum questionamento.
#
# **Cada grupo pode utilizar nas respostas objetivas quaisquer itens necessários que enriqueçam seu ponto vista, como gráficos, fotos e, até mesmo, trechos de código-fonte.**
#
# Pode-se utilizar quantos blocos forem necessários para realizar determinadas implementações ou utilizá-las para justificar as respostas. Não é obrigatório utilizar somente o bloco indicado.
#
# Ao final não se esqueça de subir os arquivos do projeto nas contas do GitHub de cada membro, ou subir na do representante do grupo e os membros realizarem o fork do projeto.
#
# A avaliação terá mais ênfase nos seguintes tópicos de desenvolvimento do projeto:
#
# 1. __Pré-Processamento__
# 2. __Classificação__
# 3. __Performance__
# 4. __Conclusões Finais__

# %% [markdown]
# ## 3.1 Detalhe do problema: a pneunomia
#
# Fonte: [artigo](https://drauziovarella.uol.com.br/doencas-e-sintomas/pneumonia) do Dr. Drauzio Varella.
#
# Pneumonias são infecções que se instalam nos pulmões, órgãos duplos localizados um de cada lado da caixa torácica. Podem acometer a região dos alvéolos pulmonares onde desembocam as ramificações terminais dos brônquios e, às vezes, os interstícios (espaço entre um alvéolo e outro).
#
# Basicamente, pneumonia é provocada pela penetração de um agente infeccioso ou irritante (bactérias, vírus, fungos e por reações alérgicas) no espaço alveolar, onde ocorre a troca gasosa. Esse local deve estar sempre muito limpo, livre de substâncias que possam impedir o contato do ar com o sangue.
#
# Exame clínico, auscultação dos pulmões e radiografias de tórax são recursos essenciais para o diagnóstico de pneumonia.
#
# <p align="center">
#     <img src="imagens/pneumonia.jpeg">
# </p>

# %% [markdown]
# ## 3.2 Diagnóstico por raio-x

# %% [markdown]
# O exame de raio-x traz diferenças em cada tipo de diagnóstico, sendo considerado os seguintes grupos de análise: **normal** (ou controle) onde não há nenhuma condição de infeção, **bacterial pneumonia** (pneumonia bacteriana) que representa a condição de infecção bacteriana e **viral pneumonia** que indica a condição de infecção vira.

# %% [markdown]
# <p align="center">
# <img src="imagens/raiox.png" height="60%" width="60%">
# </p>

# %% [markdown]
# As imagens de controle não são mais brancas ao centro que é onde fica o coração. Já nas imagens com pneumonia é possível notar regiões brancas ao redor dos pulmões, que é como o exame identifica as secreções responsáveis pela infeçcão.
#
# Quando mais regiões brancas ao redor do pulmão mais severa é a inflamação e menos se observa dos detalhes dos pulmões, ficando um pouco esmaecido diante desta condição.

# %% [markdown]
# ## 4.1 Problema
#
# Construir um classificador utilizando _transfer learning_ para identificar as seguintes classes: **controle**, **pneumonia bacteriana** e **pneumonia viral**.
#
# Para construir este classificador, utilize o dataset do [Kaggle Chest Ray Pneumonia](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) e organize os dados de forma a separar em cada uma das classes que já estão definidas no diretório ```raiox```, sendo ```controle``` para as imagens normais (sem inflamação), ```bacteria``` para as imagens de pneumonia bacteriana e ```viral``` para as imagens de pneumonia viral.
#
# Determine a quantidade de imagens a serem treinadas e validadas. Utiliza pelo menos, 100 imagens para cada classe.
#
# Compare os resultados com pelo menos 3 classificadores, obtendo os valores de **precisão (precision)**, **sensibilidade (recall)** e **pontuação F1 (F1 Score)**. No guia abaixo, foi indicado os seguintes modelos: ResNet50, VGG16 e VGG19.
#
# >Importante: a escolha do número de imagens devem ser o suficiente para alcançar o valor de **precisão** mínima de 70%.
#
# A construção do modelo será utilizada o framework Keras.

# %% [markdown]
# **Pergunta**: Qual o número de imagens que foram selecionadas para cada classe?

# %% [markdown]
# **Resposta: Foram selecionadas:

# %% [markdown]
# ## 4.2 Componentes obrigatórios
#
# Este projeto requer a instalação dos seguintes componentes, via ```conda install```:
#
# * Keras
# * Tensorflow
# * Pillow
# * Matplotlib

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %matplotlib inline

import keras
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import ResNet50
from keras.applications import VGG16, VGG19
from keras.applications import Xception
from keras.applications.xception import preprocess_input
from keras.applications.resnet50 import preprocess_input
from keras.applications.vgg16 import preprocess_input
from keras import Model, layers
from keras.models import load_model, model_from_json
from keras.utils import to_categorical
import pathlib

import keras.backend as K
import cv2
import glob
import seaborn as sns
import pandas as pd
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from os import listdir, walk
from os.path import isfile, join

# %% [markdown]
# #### Pré-processamento

# %% [markdown]
# Inicialmente, checaremos a dimensão das imagens, já que este é um fator determinante na perfomance do nosso classficador e no processamento do modelo.

# %%
os.listdir(path='./Imagens_kaggle')

def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            if entry.endswith(".jpeg"):
                allFiles.append(fullPath)
                
    return allFiles

files = getListOfFiles("./Imagens_kaggle/")

# %%
def retorna_classificacao(files):
    classificacao = []
    for file in files:
        tipo = ''
        controle = os.path.dirname(file).split("\\")[-1].lower()
        if controle == "pneumonia":
            controle = os.path.basename(file).split('_')[1]
            if controle == "virus":
                controle = "viral"
            elif controle == "bacteria":
                controle = 'bacteria'
        else:
            controle = "controle"
        classificacao.append(controle)
    return classificacao

# %%
classificacao = retorna_classificacao(files)
altura = []
comprimento = []
for file in files:
    imagem = cv2.imread(file, cv2.IMREAD_GRAYSCALE)
    altura.append(imagem.shape[0])
    comprimento.append(imagem.shape[1])
df = pd.DataFrame({'altura': altura, 'comprimento': comprimento, 'arquivo': files, 'classificacao': classificacao})

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 7))
sns.histplot(data=df, x="altura", kde=True, ax=axs[0],  color="c")
sns.histplot(data=df, x="comprimento", kde=True,ax=axs[1], palette="ch:.25")
sns.histplot(data=df, x="classificacao", discrete= True,ax=axs[2], hue='classificacao')
plt.show()

# %%
df = pd.DataFrame({'altura': altura, 'comprimento': comprimento, 'arquivo': files, 'classificacao': classificacao})

# %%
g = sns.FacetGrid(df, col="classificacao", hue="classificacao")
g.map_dataframe(sns.histplot, x="altura")
g.set_axis_labels("altura", "Observações")
s = sns.FacetGrid(df, col="classificacao", hue="classificacao")
s.map_dataframe(sns.histplot, x="comprimento")
s.set_axis_labels("comprimento", "Observações")

# %%
df[['altura', 'comprimento']].describe()
# Out:
#             altura  comprimento
# count  5856.000000  5856.000000
# mean    970.689037  1327.880806
# std     383.392117   363.500922
# min     127.000000   384.000000
# 25%     688.000000  1056.000000
# 50%     888.000000  1281.000000
# 75%    1187.000000  1560.000000
# max    2713.000000  2916.000000

# %% [markdown]
# Observamos uma grande dispersão nos comprimentos e alturas das imagens. Incialmente, selecionaremos as imagens com altura 600-1150 e comprimento 1000-1400

# %%
df[(df['comprimento'] >= 1000) & (df['comprimento']<=2000) & (df['altura']<=1400) & (df['altura'] >=600)].groupby(['classificacao'], as_index=False).size()
# Out:
#   classificacao  size
# 0      bacteria  1831
# 1      controle   936
# 2         viral  1106

# %%
df['selecionado'] = df[['altura', 'comprimento']].apply(lambda x: 1 if ((x['comprimento'] > 1000) & (x['comprimento'] < 1400) & (x['altura']>=600) & (x['altura']<=1400)) else 0, axis=1)
df_normal = df[(df['selecionado'] == 1) & (df['classificacao'] == 'controle')]
df_bacteriana = df[(df['selecionado'] == 1) & (df['classificacao'] == 'bacteria')][1:239]
df_virus = df[(df['selecionado'] == 1) & (df['classificacao'] == 'virus')][1:239]
df_selecao = pd.concat([df_normal, df_bacteriana, df_virus])

# %% [markdown]
# Antes de treinarmos os modelos, faremos o redimensionamento da imagem, processo de suavização gaussiana da imagem e limiarização invertida

# %%
# Criação de diretório para salvar as imagens
! mkdir raiox\train\controle
! mkdir raiox\train\bacteria
! mkdir raiox\train\virus

# %%
def ajuste_imagem(file, classificacao):
    imagem = cv2.imread(file)
    # Lendo o arquivo em escala de cinza para aplicação da limiarização invertida
    imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
    imagem = cv2.resize(imagem, (128, 128))
    imagem_suave_gaussian = cv2.GaussianBlur(imagem, (15, 15), 0)
    imagem_limiarizada = cv2.adaptiveThreshold(imagem_suave_gaussian, 127, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)
    cv2.imwrite("./raiox/train/" + classificacao + "/" + str(os.path.basename(file)), imagem_limiarizada)

# %%
for x, y in zip(df_selecao['arquivo'].tolist(), df_selecao['classificacao'].tolist()):
    ajuste_imagem(x,y)

# %%
# Gerando os objetos para treino
labels = df_selecao['classificacao'].tolist()
classificacao = df_selecao['classificacao'].tolist()
data = []
arquivos = df_selecao['arquivo'].tolist() 
for x, y in zip(arquivos, classificacao):
    data.append(ajuste_imagem(x, y))
data = np.array(data)
labels = np.array(labels)

# Aplicando o one-hot encoding para os rótulos
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# %% [markdown]
# ## 4.3 Carregando imagens de treinamento e validação
#
# Selecione a melhor divisão entre dados de treinamento e validação. O número deverá ser representado em número fracionário, 5% equivale a 0.05, por exemplo.}

# %%
## IMPLEMENTE
divisao_treino_validacao = 0.30
#(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=divisao_treino_validacao, stratify=labels, random_state=42)

# %%
train_datagen = ImageDataGenerator(
    shear_range=10,
    zoom_range=0.2,
    horizontal_flip=True,
    preprocessing_function=preprocess_input,
    validation_split=divisao_treino_validacao
)
train_generator = train_datagen.flow_from_directory(
    "./raiox/train/",
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="training")
# Out:
# Found 328 images belonging to 3 classes.

# %%
val_generator = train_datagen.flow_from_directory(
    "./raiox/train/",
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="validation")
# Out:
# Found 140 images belonging to 3 classes.

# %%
train_generator.class_indices, val_generator.class_indices
# Out:
# ({'bacteria': 0, 'controle': 1, 'virus': 2},
#  {'bacteria': 0, 'controle': 1, 'virus': 2})

# %% [markdown]
# ## 4.4 Modelos de transfer learning
#
# O Keras já possui classes especializadas para os seguintes modelos de deep-learning treinados com o conjunto de dados [ImageNet](http://www.image-net.org/):
#
# * Xception
# * VGG16
# * VGG19
# * ResNet50
# * InceptionV3
# * InceptionResNetV2
# * MobileNet
# * DenseNet
# * NASNet
# * MobileNetV2
#
# Mais detalhes, veja na [documentação do Keras](https://keras.io/applications/).

# %% [markdown]
# Para este estudo, vamos utilizar para avaliação as seguintes arquiteturas: RestNet50, VGG15 e VGG19.

# %% [markdown]
# ## 4.5 Indicadores de desempenho
#
# O Keras não possui os indicadores de desempenho como precisão, sensibilidade e pontuação f1 por padrão, portanto precisamos implementar externamente.

# %%
def recall_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_score(y_true, y_pred):
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ### 4.5.1 Arquitetura ResNet50

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do ResNet50? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:**Resposta**:
#     A ResNet50 é uma variação da ResNet, Residual Network, que possui 50 camadas convulacionais, que é de onde vem o número 50 do nome.
#     Essa arquitetura é muito utilizada em tarefas de visão computacional como classificação de imagem, localização de objetos, detecção de objetos, etc.
#
#     Abaixo segue imagem ilustrando as camadas da ResNet50:

# %%
from IPython.display import Image
Image('./imagens/The-architecture-of-ResNet50-and-deep-learning-model-flowchart-a-b-Architecture-of.jpg',width=900, height=1000)

# %% [markdown]
# A técnica de transfer learning consiste de utilizar o mesmo modelo e treiná-lo para outas imagens. Por tal motivo, excluímos a última camada para modelar com as classes que definimos, ou seja, **controle**, **bacteriana** e **viral**.

# %% [markdown]
# Informe a quantidade de classes a serem classificadas.

# %%
## IMPLEMENTE

qtde_classes = 3

# %%
conv_base = ResNet50(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, None, None, 6 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, None, None, 6 4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, None, None, 6 256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, None, None, 6 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, None, None, 6 256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, None, None, 6 0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, None, None, 2 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, None, None, 2 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, None, None, 2 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, None, None, 2 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, None, None, 6 16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, None, None, 6 256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, None, None, 6 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, None, None, 6 256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, None, None, 6 0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, None, None, 2 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, None, None, 2 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, None, None, 6 16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, None, None, 6 256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, None, None, 6 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, None, None, 6 256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, None, None, 6 0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, None, None, 2 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, None, None, 2 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, None, None, 1 32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, None, None, 1 512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, None, None, 1 0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, None, None, 1 512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, None, None, 1 0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, None, None, 5 131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, None, None, 5 2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, None, None, 5 0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, None, None, 5 0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, None, None, 1 512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, None, None, 1 0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, None, None, 1 512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, None, None, 1 0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, None, None, 5 0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, None, None, 5 0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, None, None, 1 512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, None, None, 1 0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, None, None, 1 512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, None, None, 1 0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, None, None, 5 0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, None, None, 5 0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, None, None, 1 512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, None, None, 1 0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, None, None, 1 512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, None, None, 1 0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, None, None, 5 0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, None, None, 5 0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, None, None, 2 131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, None, None, 2 0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, None, None, 2 0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, None, None, 1 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, None, None, 1 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, None, None, 1 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, None, None, 1 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, None, None, 2 0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, None, None, 2 0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, None, None, 1 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, None, None, 1 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, None, None, 2 0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, None, None, 2 0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, None, None, 1 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, None, None, 1 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, None, None, 2 0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, None, None, 2 0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, None, None, 1 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, None, None, 1 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, None, None, 2 0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, None, None, 2 0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, None, None, 1 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, None, None, 1 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, None, None, 2 0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, None, None, 2 0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, None, None, 1 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, None, None, 1 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, None, None, 5 524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, None, None, 5 0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, None, None, 5 0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, None, None, 2 2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, None, None, 2 8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, None, None, 2 0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, None, None, 2 0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, None, None, 5 1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, None, None, 5 0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, None, None, 5 0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, None, None, 2 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, None, None, 2 0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, None, None, 5 1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, None, None, 5 0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, None, None, 5 0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, None, None, 2 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, None, None, 2 0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          262272      global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 3)            387         dense[0][0]
# ==================================================================================================
# Total params: 23,850,371
# Trainable params: 262,659
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %% [markdown]
# O número de épocas define quantas vezes o modelo irá treinar e validar o erro, assim ajustando os pesos para melhor convergência.
# Escolha o número adequado de épocas para alcançarmos pelo menos **70% de precisão de validação**.

# %%
## IMPLEMENTE

qtde_epocas = 100

# %%
history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 29s 7s/step - loss: 0.5224 - precision_score: 0.7812 - recall_score: 0.7812 - f1_score: 0.7812 - val_loss: 0.3998 - val_precision_score: 0.8354 - val_recall_score: 0.8354 - val_f1_score: 0.8354
# Epoch 2/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.4100 - precision_score: 0.7500 - recall_score: 0.7500 - f1_score: 0.7500 - val_loss: 0.3783 - val_precision_score: 0.8833 - val_recall_score: 0.8833 - val_f1_score: 0.8833
# Epoch 3/100
# 5/5 [==============================] - 32s 7s/step - loss: 0.4897 - precision_score: 0.7625 - recall_score: 0.7625 - f1_score: 0.7625 - val_loss: 0.3569 - val_precision_score: 0.8375 - val_recall_score: 0.8375 - val_f1_score: 0.8375
# Epoch 4/100
# 5/5 [==============================] - 33s 7s/step - loss: 0.4836 - precision_score: 0.7875 - recall_score: 0.7875 - f1_score: 0.7875 - val_loss: 0.4191 - val_precision_score: 0.8104 - val_recall_score: 0.8104 - val_f1_score: 0.8104
# Epoch 5/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.4850 - precision_score: 0.7812 - recall_score: 0.7812 - f1_score: 0.7812 - val_loss: 0.4088 - val_precision_score: 0.8333 - val_recall_score: 0.8333 - val_f1_score: 0.8333
# Epoch 6/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.4302 - precision_score: 0.8000 - recall_score: 0.8000 - f1_score: 0.8000 - val_loss: 0.3600 - val_precision_score: 0.8354 - val_recall_score: 0.8354 - val_f1_score: 0.8354
# Epoch 7/100
# 5/5 [==============================] - 32s 7s/step - loss: 0.4374 - precision_score: 0.7750 - recall_score: 0.7750 - f1_score: 0.7750 - val_loss: 0.3363 - val_precision_score: 0.8521 - val_recall_score: 0.8521 - val_f1_score: 0.8521
# Epoch 8/100
# 5/5 [==============================] - 34s 8s/step - loss: 0.3637 - precision_score: 0.7937 - recall_score: 0.7937 - f1_score: 0.7937 - val_loss: 0.2836 - val_precision_score: 0.8896 - val_recall_score: 0.8896 - val_f1_score: 0.8896
# Epoch 9/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.4352 - precision_score: 0.8375 - recall_score: 0.8375 - f1_score: 0.8375 - val_loss: 0.3339 - val_precision_score: 0.8708 - val_recall_score: 0.8708 - val_f1_score: 0.8708
# Epoch 10/100
# 5/5 [==============================] - 34s 7s/step - loss: 0.3344 - precision_score: 0.8625 - recall_score: 0.8625 - f1_score: 0.8625 - val_loss: 0.4093 - val_precision_score: 0.8167 - val_recall_score: 0.8167 - val_f1_score: 0.8167
# Epoch 11/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.3656 - precision_score: 0.8188 - recall_score: 0.8188 - f1_score: 0.8187 - val_loss: 0.4700 - val_precision_score: 0.7917 - val_recall_score: 0.7917 - val_f1_score: 0.7917
# Epoch 12/100
# 5/5 [==============================] - 33s 7s/step - loss: 0.4011 - precision_score: 0.8250 - recall_score: 0.8250 - f1_score: 0.8250 - val_loss: 0.3628 - val_precision_score: 0.8354 - val_recall_score: 0.8354 - val_f1_score: 0.8354
# Epoch 13/100
# 5/5 [==============================] - 31s 8s/step - loss: 0.3394 - precision_score: 0.8687 - recall_score: 0.8687 - f1_score: 0.8687 - val_loss: 0.4104 - val_precision_score: 0.8167 - val_recall_score: 0.8167 - val_f1_score: 0.8167
# Epoch 14/100
# 5/5 [==============================] - 35s 8s/step - loss: 0.4015 - precision_score: 0.8125 - recall_score: 0.8125 - f1_score: 0.8125 - val_loss: 0.4090 - val_precision_score: 0.8042 - val_recall_score: 0.8042 - val_f1_score: 0.8042
# Epoch 15/100
# 5/5 [==============================] - 34s 8s/step - loss: 0.3833 - precision_score: 0.8125 - recall_score: 0.8125 - f1_score: 0.8125 - val_loss: 0.2358 - val_precision_score: 0.9125 - val_recall_score: 0.9125 - val_f1_score: 0.9125
# Epoch 16/100
# 5/5 [==============================] - 33s 7s/step - loss: 0.3422 - precision_score: 0.8313 - recall_score: 0.8313 - f1_score: 0.8312 - val_loss: 0.2781 - val_precision_score: 0.8813 - val_recall_score: 0.8813 - val_f1_score: 0.8812
# Epoch 17/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.3192 - precision_score: 0.8813 - recall_score: 0.8813 - f1_score: 0.8812 - val_loss: 0.3270 - val_precision_score: 0.8729 - val_recall_score: 0.8729 - val_f1_score: 0.8729
# Epoch 18/100
# 5/5 [==============================] - 33s 7s/step - loss: 0.2820 - precision_score: 0.8875 - recall_score: 0.8875 - f1_score: 0.8875 - val_loss: 0.3241 - val_precision_score: 0.8771 - val_recall_score: 0.8771 - val_f1_score: 0.8771
# Epoch 19/100
# 5/5 [==============================] - 33s 7s/step - loss: 0.4415 - precision_score: 0.8375 - recall_score: 0.8375 - f1_score: 0.8375 - val_loss: 0.3155 - val_precision_score: 0.8667 - val_recall_score: 0.8667 - val_f1_score: 0.8667
# Epoch 20/100
# 5/5 [==============================] - 33s 7s/step - loss: 0.3200 - precision_score: 0.8813 - recall_score: 0.8813 - f1_score: 0.8812 - val_loss: 0.3193 - val_precision_score: 0.8500 - val_recall_score: 0.8500 - val_f1_score: 0.8500
# Epoch 21/100
# 5/5 [==============================] - 33s 7s/step - loss: 0.3287 - precision_score: 0.8562 - recall_score: 0.8562 - f1_score: 0.8562 - val_loss: 0.2932 - val_precision_score: 0.9375 - val_recall_score: 0.9375 - val_f1_score: 0.9375
# Epoch 22/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.3090 - precision_score: 0.8813 - recall_score: 0.8813 - f1_score: 0.8813 - val_loss: 0.2998 - val_precision_score: 0.8896 - val_recall_score: 0.8896 - val_f1_score: 0.8896
# Epoch 23/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.
# Epoch 50/100
# 5/5 [==============================] - 37s 8s/step - loss: 0.3180 - precision_score: 0.8438 - recall_score: 0.8438 - f1_score: 0.8437 - val_loss: 0.2801 - val_precision_score: 0.8792 - val_recall_score: 0.8792 - val_f1_score: 0.8792
# Epoch 51/100
# 5/5 [==============================] - 35s 8s/step - loss: 0.3312 - precision_score: 0.8813 - recall_score: 0.8813 - f1_score: 0.8812 - val_loss: 0.2277 - val_precision_score: 0.9042 - val_recall_score: 0.9042 - val_f1_score: 0.9042
# Epoch 52/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2489 - precision_score: 0.9187 - recall_score: 0.9187 - f1_score: 0.9187 - val_loss: 0.2310 - val_precision_score: 0.9208 - val_recall_score: 0.9208 - val_f1_score: 0.9208
# Epoch 53/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2577 - precision_score: 0.9062 - recall_score: 0.9062 - f1_score: 0.9062 - val_loss: 0.2570 - val_precision_score: 0.8896 - val_recall_score: 0.8896 - val_f1_score: 0.8896
# Epoch 54/100
# 5/5 [==============================] - 34s 8s/step - loss: 0.3097 - precision_score: 0.8625 - recall_score: 0.8625 - f1_score: 0.8625 - val_loss: 0.2615 - val_precision_score: 0.8813 - val_recall_score: 0.8813 - val_f1_score: 0.8812
# Epoch 55/100
# 5/5 [==============================] - 32s 7s/step - loss: 0.2634 - precision_score: 0.8938 - recall_score: 0.8938 - f1_score: 0.8938 - val_loss: 0.2406 - val_precision_score: 0.9167 - val_recall_score: 0.9167 - val_f1_score: 0.9167
# Epoch 56/100
# 5/5 [==============================] - 32s 7s/step - loss: 0.2718 - precision_score: 0.8687 - recall_score: 0.8687 - f1_score: 0.8687 - val_loss: 0.3360 - val_precision_score: 0.8646 - val_recall_score: 0.8646 - val_f1_score: 0.8646
# Epoch 57/100
# 5/5 [==============================] - 33s 7s/step - loss: 0.2239 - precision_score: 0.9312 - recall_score: 0.9312 - f1_score: 0.9312 - val_loss: 0.2435 - val_precision_score: 0.8896 - val_recall_score: 0.8896 - val_f1_score: 0.8896
# Epoch 58/100
# 5/5 [==============================] - 32s 7s/step - loss: 0.2427 - precision_score: 0.8875 - recall_score: 0.8875 - f1_score: 0.8875 - val_loss: 0.3017 - val_precision_score: 0.8500 - val_recall_score: 0.8500 - val_f1_score: 0.8500
# Epoch 59/100
# 5/5 [==============================] - 33s 7s/step - loss: 0.2108 - precision_score: 0.9250 - recall_score: 0.9250 - f1_score: 0.9250 - val_loss: 0.3313 - val_precision_score: 0.8521 - val_recall_score: 0.8521 - val_f1_score: 0.8521
# Epoch 60/100
# 5/5 [==============================] - 32s 7s/step - loss: 0.3980 - precision_score: 0.8000 - recall_score: 0.8000 - f1_score: 0.8000 - val_loss: 0.3027 - val_precision_score: 0.8833 - val_recall_score: 0.8833 - val_f1_score: 0.8833
# Epoch 61/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.2694 - precision_score: 0.8938 - recall_score: 0.8938 - f1_score: 0.8937 - val_loss: 0.2826 - val_precision_score: 0.8438 - val_recall_score: 0.8438 - val_f1_score: 0.8437
# Epoch 62/100
# 5/5 [==============================] - 28s 6s/step - loss: 0
100
# 5/5 [==============================] - 30s 7s/step - loss: 0.1912 - precision_score: 0.9250 - recall_score: 0.9250 - f1_score: 0.9250 - val_loss: 0.2184 - val_precision_score: 0.9333 - val_recall_score: 0.9333 - val_f1_score: 0.9333
# Epoch 90/100
# 5/5 [==============================] - 29s 7s/step - loss: 0.2611 - precision_score: 0.9000 - recall_score: 0.9000 - f1_score: 0.9000 - val_loss: 0.2741 - val_precision_score: 0.8458 - val_recall_score: 0.8458 - val_f1_score: 0.8458
# Epoch 91/100
# 5/5 [==============================] - 29s 7s/step - loss: 0.3050 - precision_score: 0.8875 - recall_score: 0.8875 - f1_score: 0.8875 - val_loss: 0.2628 - val_precision_score: 0.8792 - val_recall_score: 0.8792 - val_f1_score: 0.8792
# Epoch 92/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2893 - precision_score: 0.8813 - recall_score: 0.8813 - f1_score: 0.8812 - val_loss: 0.2448 - val_precision_score: 0.9021 - val_recall_score: 0.9021 - val_f1_score: 0.9021
# Epoch 93/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.1759 - precision_score: 0.9250 - recall_score: 0.9250 - f1_score: 0.9250 - val_loss: 0.2822 - val_precision_score: 0.8729 - val_recall_score: 0.8729 - val_f1_score: 0.8729
# Epoch 94/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.2185 - precision_score: 0.8875 - recall_score: 0.8875 - f1_score: 0.8875 - val_loss: 0.2216 - val_precision_score: 0.9271 - val_recall_score: 0.9271 - val_f1_score: 0.9271
# Epoch 95/100
# 5/5 [==============================] - 32s 7s/step - loss: 0.1989 - precision_score: 0.9062 - recall_score: 0.9062 - f1_score: 0.9062 - val_loss: 0.2387 - val_precision_score: 0.9042 - val_recall_score: 0.9042 - val_f1_score: 0.9042
# Epoch 96/100
# 5/5 [==============================] - 32s 7s/step - loss: 0.1975 - precision_score: 0.9125 - recall_score: 0.9125 - f1_score: 0.9125 - val_loss: 0.1942 - val_precision_score: 0.9375 - val_recall_score: 0.9375 - val_f1_score: 0.9375
# Epoch 97/100
# 5/5 [==============================] - 29s 6s/step - loss: 0.1845 - precision_score: 0.9500 - recall_score: 0.9500 - f1_score: 0.9500 - val_loss: 0.2292 - val_precision_score: 0.8729 - val_recall_score: 0.8729 - val_f1_score: 0.8729
# Epoch 98/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.1956 - precision_score: 0.9563 - recall_score: 0.9563 - f1_score: 0.9563 - val_loss: 0.2234 - val_precision_score: 0.9146 - val_recall_score: 0.9146 - val_f1_score: 0.9146
# Epoch 99/100
# 5/5 [==============================] - 33s 7s/step - loss: 0.2414 - precision_score: 0.9062 - recall_score: 0.9062 - f1_score: 0.9062 - val_loss: 0.1911 - val_precision_score: 0.8958 - val_recall_score: 0.8958 - val_f1_score: 0.8958
# Epoch 100/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.1909 - precision_score: 0.9563 - recall_score: 0.9563 - f1_score: 0.9563 - val_loss: 0.2077 - val_precision_score: 0.9187 - val_recall_score: 0.9187 - val_f1_score: 0.9187

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**: Para todos os indicadores o valor foi de 91,87%

# %% [markdown]
# ### 4.5.2 Arquitetura VGG16

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG16? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:A VGG 16 é uma rede neural convulucional proposta por pesquisadores da Universidade de Oxford. Considerando o dataset da ImageNet, o modelo atinge precisão de 92,7% nos top5 testes efetuados. Ela é composta pela sequencialmente pelas seguintes camadas:
# - 2 Camadas Convolucionais
# - 1 de Pooling
# - 2 Camadas Convolucionais
# - 1 de pooling
# - 3 camadas convolucionais
# - 1 de Pooling
# - 3 camadas convolucionais
# - 1 de Pooling
# - 3 camadas convolucionais
# - 1 de Pooling
# - 3 camadas densas
# São conhecidos alguns inconvenientes da VGG16. Entre eles:
# - Lentidão para treinamento
# - A arquitetura dos pesos é muito extensa, o que pode gerar problemas de memória
#
# Abaixo segue imagem para exemplificar a arquitetura:

# %%
Image('./imagens/vgg16.png',width=900, height=1000)

# %%
conv_base = VGG16(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 14,780,739
# Trainable params: 66,051
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 28s 6s/step - loss: 1.0082 - precision_score: 0.5486 - recall_score: 0.5434 - f1_score: 0.5460 - val_loss: 1.0946 - val_precision_score: 0.5583 - val_recall_score: 0.5583 - val_f1_score: 0.5583
# Epoch 2/100
# 5/5 [==============================] - 27s 6s/step - loss: 1.0444 - precision_score: 0.5548 - recall_score: 0.5548 - f1_score: 0.5548 - val_loss: 0.5599 - val_precision_score: 0.7417 - val_recall_score: 0.7417 - val_f1_score: 0.7417
# Epoch 3/100
100
# 5/5 [==============================] - 24s 5s/step - loss: 0.4213 - precision_score: 0.8170 - recall_score: 0.8170 - f1_score: 0.8170 - val_loss: 0.4395 - val_precision_score: 0.7708 - val_recall_score: 0.7708 - val_f1_score: 0.7708
# Epoch 17/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.4457 - precision_score: 0.8418 - recall_score: 0.8418 - f1_score: 0.8418 - val_loss: 0.3756 - val_precision_score: 0.8229 - val_recall_score: 0.8229 - val_f1_score: 0.8229
# Epoch 18/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.4637 - precision_score: 0.7590 - recall_score: 0.7590 - f1_score: 0.7590 - val_loss: 0.3496 - val_precision_score: 0.8458 - val_recall_score: 0.8458 - val_f1_score: 0.8458
# Epoch 19/100
# 5/5 [==============================] - 26s 6s/step - loss: 0.3115 - precision_score: 0.8464 - recall_score: 0.8464 - f1_score: 0.8464 - val_loss: 0.3533 - val_precision_score: 0.8521 - val_recall_score: 0.8521 - val_f1_score: 0.8521
# Epoch 20/100
# 5/5 [==============================] - 26s 6s/step - loss: 0.5119 - precision_score: 0.7385 - recall_score: 0.7385 - f1_score: 0.7385 - val_loss: 0.3554 - val_precision_score: 0.8250 - val_recall_score: 0.8250 - val_f1_score: 0.8250
# Epoch 21/100
# 5/5 [==============================] - 26s 6s/step - loss: 0.4129 - precision_score: 0.8349 - recall_score: 0.8349 - f1_score: 0.8349 - val_loss: 0.3636 - val_precision_score: 0.8333 - val_recall_score: 0.8333 - val_f1_score: 0.8333
# Epoch 22/100
# 5/5 [==============================] - 26s 6s/step - loss: 0.3301 - precision_score: 0.8467 - recall_score: 0.8467 - f1_score: 0.8467 - val_loss: 0.3050 - val_precision_score: 0.8958 - val_recall_score: 0.8958 - val_f1_score: 0.8958
# Epoch 23/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.3441 - precision_score: 0.8679 - recall_score: 0.8679 - f1_score: 0.8679 - val_loss: 0.4142 - val_precision_score: 0.8521 - val_recall_score: 0.8521 - val_f1_score: 0.8521
# Epoch 24/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.3086 - precision_score: 0.8499 - recall_score: 0.8499 - f1_score: 0.8499 - val_loss: 0.3327 - val_precision_score: 0.8833 - val_recall_score: 0.8833 - val_f1_score: 0.8833
# Epoch 25/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.3161 - precision_score: 0.8879 - recall_score: 0.8879 - f1_score: 0.8879 - val_loss: 0.3129 - val_precision_score: 0.8521 - val_recall_score: 0.8521 - val_f1_score: 0.8521
# Epoch 26/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.2917 - precision_score: 0.8873 - recall_score: 0.8873 - f1_score: 0.8873 - val_loss: 0.3294 - val_precision_score: 0.8667 - val_recall_score: 0.8667 - val_f1_score: 0.8667
# Epoch 27/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.4110 - precision_score: 0.8099 - recall_score: 0.8099 - f1_score: 0.8099 - val_loss: 0.2971 - val_precision_score: 0.8667 - val_recall_score: 0.8667 - val_f1_score: 0.8667
# Epoch 28/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.3244 - precision_score: 0.8702 - recall_score: 0.8702 - f1_score: 0.8702 - val_loss: 0.3562 - val_precision_score: 0.8729 - val_recall_score: 0.8729 - val_f1_score: 0.8729
# Epoch 29/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.3185 - precision_score: 0.9047 - recall_score: 0.9047 - f1_score: 0.9047 - val_loss: 0.3336 - val_precision_score: 0.8875 - val_recall_score: 0.8875 - val_f1_score: 0.8875
# Epoch 30/100
# 5/5 [==============================] - 24s 5s/step - loss: 0
100
# 5/5 [==============================] - 25s 6s/step - loss: 0.2238 - precision_score: 0.9128 - recall_score: 0.9128 - f1_score: 0.9128 - val_loss: 0.2714 - val_precision_score: 0.8625 - val_recall_score: 0.8625 - val_f1_score: 0.8625
# Epoch 75/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.2627 - precision_score: 0.8639 - recall_score: 0.8639 - f1_score: 0.8639 - val_loss: 0.3295 - val_precision_score: 0.8646 - val_recall_score: 0.8646 - val_f1_score: 0.8646
# Epoch 76/100
# 5/5 [==============================] - 23s 6s/step - loss: 0.3114 - precision_score: 0.8684 - recall_score: 0.8684 - f1_score: 0.8684 - val_loss: 0.2595 - val_precision_score: 0.8958 - val_recall_score: 0.8958 - val_f1_score: 0.8958
# Epoch 77/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.2677 - precision_score: 0.8933 - recall_score: 0.8933 - f1_score: 0.8933 - val_loss: 0.3079 - val_precision_score: 0.8833 - val_recall_score: 0.8833 - val_f1_score: 0.8833
# Epoch 78/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.2182 - precision_score: 0.9140 - recall_score: 0.9140 - f1_score: 0.9140 - val_loss: 0.2498 - val_precision_score: 0.8896 - val_recall_score: 0.8896 - val_f1_score: 0.8896
# Epoch 79/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.2479 - precision_score: 0.8801 - recall_score: 0.8801 - f1_score: 0.8801 - val_loss: 0.4142 - val_precision_score: 0.8479 - val_recall_score: 0.8479 - val_f1_score: 0.8479
# Epoch 80/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.2510 - precision_score: 0.8891 - recall_score: 0.8891 - f1_score: 0.8891 - val_loss: 0.2773 - val_precision_score: 0.8792 - val_recall_score: 0.8792 - val_f1_score: 0.8792
# Epoch 81/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.2603 - precision_score: 0.8844 - recall_score: 0.8844 - f1_score: 0.8844 - val_loss: 0.4326 - val_precision_score: 0.7917 - val_recall_score: 0.7917 - val_f1_score: 0.7917
# Epoch 82/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.3252 - precision_score: 0.8493 - recall_score: 0.8493 - f1_score: 0.8493 - val_loss: 0.2393 - val_precision_score: 0.9146 - val_recall_score: 0.9146 - val_f1_score: 0.9146
# Epoch 83/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.2120 - precision_score: 0.9195 - recall_score: 0.9195 - f1_score: 0.9195 - val_loss: 0.4218 - val_precision_score: 0.8708 - val_recall_score: 0.8708 - val_f1_score: 0.8708
# Epoch 84/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.2267 - precision_score: 0.8832 - recall_score: 0.8832 - f1_score: 0.8832 - val_loss: 0.2270 - val_precision_score: 0.9250 - val_recall_score: 0.9250 - val_f1_score: 0.9250
# Epoch 85/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.2251 - precision_score: 0.8880 - recall_score: 0.8880 - f1_score: 0.8880 - val_loss: 0.3394 - val_precision_score: 0.8188 - val_recall_score: 0.8188 - val_f1_score: 0.8187
# Epoch 86/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.2674 - precision_score: 0.9058 - recall_score: 0.9058 - f1_score: 0.9058 - val_loss: 0.3612 - val_precision_score: 0.8333 - val_recall_score: 0.8333 - val_f1_score: 0.8333
# Epoch 87/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.2553 - precision_score: 0.8679 - recall_score: 0.8679 - f1_score: 0.8679 - val_loss: 0.5116 - val_precision_score: 0.8021 - val_recall_score: 0.8021 - val_f1_score: 0.8021
# Epoch 88/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.2721 - precision_score: 0.9040 - recall_score: 0.9040 - f1_score: 0.9040 - val_loss: 0.3449 - val_precision_score: 0.8625 - val_recall_score: 0.8625 - val_f1_score: 0.8625
# Epoch 89/100
# 5/5 [==============================] - 23s 6s/step - loss: 0.2342 - precision_score: 0.9302 - recall_score: 0.9302 - f1_score: 0.9302 - val_loss: 0.4256 - val_precision_score: 0.8292 - val_recall_score: 0.8292 - val_f1_score: 0.8292
# Epoch 90/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.2447 - precision_score: 0.9246 - recall_score: 0.9246 - f1_score: 0.9246 - val_loss: 0.4098 - val_precision_score: 0.8521 - val_recall_score: 0.8521 - val_f1_score: 0.8521
# Epoch 91/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.3005 - precision_score: 0.8475 - recall_score: 0.8475 - f1_score: 0.8475 - val_loss: 0.2840 - val_precision_score: 0.9021 - val_recall_score: 0.9021 - val_f1_score: 0.9021
# Epoch 92/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.2889 - precision_score: 0.8686 - recall_score: 0.8686 - f1_score: 0.8686 - val_loss: 0.2953 - val_precision_score: 0.8833 - val_recall_score: 0.8833 - val_f1_score: 0.8833
# Epoch 93/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.2636 - precision_score: 0.8875 - recall_score: 0.8875 - f1_score: 0.8875 - val_loss: 0.3435 - val_precision_score: 0.9062 - val_recall_score: 0.9062 - val_f1_score: 0.9062
# Epoch 94/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.4023 - precision_score: 0.8328 - recall_score: 0.8328 - f1_score: 0.8328 - val_loss: 0.3102 - val_precision_score: 0.8792 - val_recall_score: 0.8792 - val_f1_score: 0.8792
# Epoch 95/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.2181 - precision_score: 0.8994 - recall_score: 0.8994 - f1_score: 0.8994 - val_loss: 0.2191 - val_precision_score: 0.9312 - val_recall_score: 0.9312 - val_f1_score: 0.9312
# Epoch 96/100
# 5/5 [==============================] - 23s 6s/step - loss: 0.1674 - precision_score: 0.9516 - recall_score: 0.9516 - f1_score: 0.9516 - val_loss: 0.3900 - val_precision_score: 0.8479 - val_recall_score: 0.8479 - val_f1_score: 0.8479
# Epoch 97/100
# 5/5 [==============================] - 23s 6s/step - loss: 0.2250 - precision_score: 0.9401 - recall_score: 0.9401 - f1_score: 0.9401 - val_loss: 0.3289 - val_precision_score: 0.8667 - val_recall_score: 0.8667 - val_f1_score: 0.8667
# Epoch 98/100
# 5/5 [==============================] - 23s 5s/step - loss: 0.2519 - precision_score: 0.8757 - recall_score: 0.8757 - f1_score: 0.8757 - val_loss: 0.2536 - val_precision_score: 0.8667 - val_recall_score: 0.8667 - val_f1_score: 0.8667
# Epoch 99/100
# 5/5 [==============================] - 25s 6s/step - loss: 0.2138 - precision_score: 0.9398 - recall_score: 0.9398 - f1_score: 0.9398 - val_loss: 0.3568 - val_precision_score: 0.8833 - val_recall_score: 0.8833 - val_f1_score: 0.8833
# Epoch 100/100
# 5/5 [==============================] - 23s 6s/step - loss: 0.2833 - precision_score: 0.8780 - recall_score: 0.8780 - f1_score: 0.8780 - val_loss: 0.3214 - val_precision_score: 0.9062 - val_recall_score: 0.9062 - val_f1_score: 0.9062

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:Os valores, rodando 100 epocas, são 90,62% para val_precision_score, val_recall_score e val_f1_score

# %% [markdown]
# ### 4.5.3 Arquitetura VGG19

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG19? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %%
conv_base = VGG19(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 20,090,435
# Trainable params: 66,051
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 31s 7s/step - loss: 3.3752 - precision_score: 0.3352 - recall_score: 0.3352 - f1_score: 0.3352 - val_loss: 1.5071 - val_precision_score: 0.5042 - val_recall_score: 0.5042 - val_f1_score: 0.5042
# Epoch 2/100
# 5/5 [==============================] - 30s 7s/step - loss: 1.5720 - precision_score: 0.5103 - recall_score: 0.5103 - f1_score: 0.5103 - val_loss: 0.7415 - val_precision_score: 0.6500 - val_recall_score: 0.6500 - val_f1_score: 0.6500
# Epoch 3/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.9282 - precision_score: 0.5522 - recall_score: 0.5522 - f1_score: 0.5522 - val_loss: 0.7041 - val_precision_score: 0.6708 - val_recall_score: 0.6708 - val_f1_score: 0.6708
# Epoch 4/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.7215 - precision_score: 0.6552 - recall_score: 0.6552 - f1_score: 0.6552 - val_loss: 0.5288 - val_precision_score: 0.7604 - val_recall_score: 0.7604 - val_f1_score: 0.7604
# Epoch 5/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.5427 - precision_score: 0.7392 - recall_score: 0.7392 - f1_score: 0.7392 - val_loss: 0.6023 - val_precision_score: 0.7479 - val_recall_score: 0.7479 - val_f1_score: 0.7479
# Epoch 6/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.7072 - precision_score: 0.6793 - recall_score: 0.6793 - f1_score: 0.6793 - val_loss: 0.4790 - val_precision_score: 0.7771 - val_recall_score: 0.7771 - val_f1_score: 0.7771
# Epoch 7/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.5154 - precision_score: 0.7569 - recall_score: 0.7569 - f1_score: 0.7569 - val_loss: 0.5063 - val_precision_score: 0.7750 - val_recall_score: 0.7750 - val_f1_score: 0.7750
# Epoch 8/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.6276 - precision_score: 0.7100 - recall_score: 0.7100 - f1_score: 0.7100 - val_loss: 0.4687 - val_precision_score: 0.7604 - val_recall_score: 0.7604 - val_f1_score: 0.7604
# Epoch 9/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.4480 - precision_score: 0.7549 - recall_score: 0.7549 - f1_score: 0.7549 - val_loss: 0.5164 - val_precision_score: 0.7875 - val_recall_score: 0.7875 - val_f1_score: 0.7875
# Epoch 10/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.5085 - precision_score: 0.7602 - recall_score: 0.7602 - f1_score: 0.7602 - val_loss: 0.4649 - val_precision_score: 0.7917 - val_recall_score: 0.7917 - val_f1_score: 0.7917
# Epoch 11/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.5301 - precision_score: 0.7374 - recall_score: 0.7374 - f1_score: 0.7374 - val_loss: 0.4366 - val_precision_score: 0.7812 - val_recall_score: 0.7812 - val_f1_score: 0.7812
# Epoch 12/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.5173 - precision_score: 0.8131 - recall_score: 0.8131 - f1_score: 0.8131 - val_loss: 0.3823 - val_precision_score: 0.8521 - val_recall_score: 0.8521 - val_f1_score: 0.8521
# Epoch 13/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.4522 - precision_score: 0.7449 - recall_score: 0.7449 - f1_score: 0.7449 - val_loss: 0.3664 - val_precision_score: 0.8750 - val_recall_score: 0.8750 - val_f1_score: 0.8750
# Epoch 14/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.5410 - precision_score: 0.7371 - recall_score: 0.7371 - f1_score: 0.7371 - val_loss: 0.4324 - val_precision_score: 0.8417 - val_recall_score: 0.8417 - val_f1_score: 0.8417
# Epoch 15/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.4391 - precision_score: 0.8033 - recall_score: 0.8033 - f1_score: 0.8033 - val_loss: 0.3780 - val_precision_score: 0.8458 - val_recall_score: 0.8458 - val_f1_score: 0.8458
# Epoch 16/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.4633 - precision_score: 0.7194 - recall_score: 0.7194 - f1_score: 0.7194 - val_loss: 0.3930 - val_precision_score: 0.8396 - val_recall_score: 0.8396 - val_f1_score: 0.8396
# Epoch 17/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.4109 - precision_score: 0.8352 - recall_score: 0.8352 - f1_score: 0.8352 - val_loss: 0.3946 - val_precision_score: 0.8292 - val_recall_score: 0.8292 - val_f1_score: 0.8292
# Epoch 18/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.3717 - precision_score: 0.8089 - recall_score: 0.8089 - f1_score: 0.8089 - val_loss: 0.4190 - val_precision_score: 0.8000 - val_recall_score: 0.8000 - val_f1_score: 0.8000
# Epoch 19/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3769 - precision_score: 0.8270 - recall_score: 0.8270 - f1_score: 0.8270 - val_loss: 0.3854 - val_precision_score: 0.8562 - val_recall_score: 0.8562 - val_f1_score: 0.8562
# Epoch 20/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.4291 - precision_score: 0.7975 - recall_score: 0.7975 - f1_score: 0.7975 - val_loss: 0.3782 - val_precision_score: 0.8271 - val_recall_score: 0.8271 - val_f1_score: 0.8271
# Epoch 21/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.4191 - precision_score: 0.7476 - recall_score: 0.7476 - f1_score: 0.7476 - val_loss: 0.3821 - val_precision_score: 0.8250 - val_recall_score: 0.8250 - val_f1_score: 0.8250
# Epoch 22/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.4130 - precision_score: 0.7986 - recall_score: 0.7986 - f1_score: 0.7986 - val_loss: 0.3517 - val_precision_score: 0.8479 - val_recall_score: 0.8479 - val_f1_score: 0.8479
# Epoch 23/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.3643 - precision_score: 0.8367 - recall_score: 0.8367 - f1_score: 0.8367 - val_loss: 0.3730 - val_precision_score: 0.8000 - val_recall_score: 0.8000 - val_f1_score: 0.8000
# Epoch 24/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3665 - precision_score: 0.8386 - recall_score: 0.8386 - f1_score: 0.8386 - val_loss: 0.3907 - val_precision_score: 0.8167 - val_recall_score: 0.8167 - val_f1_score: 0.8167
# Epoch 25/100
# 5/5 [==============================] - 28s 7s/step - loss: 0.3799 - precision_score: 0.8408 - recall_score: 0.8408 - f1_score: 0.8408 - val_loss: 0.3711 - val_precision_score: 0.8292 - val_recall_score: 0.8292 - val_f1_score: 0.8292
# Epoch 26/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3970 - precision_score: 0.8149 - recall_score: 0.8149 - f1_score: 0.8149 - val_loss: 0.3641 - val_precision_score: 0.8958 - val_recall_score: 0.8958 - val_f1_score: 0.8958
# Epoch 27/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.4049 - precision_score: 0.7984 - recall_score: 0.7984 - f1_score: 0.7984 - val_loss: 0.3284 - val_precision_score: 0.8771 - val_recall_score: 0.8771 - val_f1_score: 0.8771
# Epoch 28/100
# 5/5 [==============================] - 31s 7s/step - loss: 0.3439 - precision_score: 0.8095 - recall_score: 0.8095 - f1_score: 0.8095 - val_loss: 0.3828 - val_precision_score: 0.8292 - val_recall_score: 0.8292 - val_f1_score: 0.8292
# Epoch 29/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3573 - precision_score: 0.8149 - recall_score: 0.8149 - f1_score: 0.8149 - val_loss: 0.3145 - val_precision_score: 0.8438 - val_recall_score: 0.8438 - val_f1_score: 0.8437
# Epoch 30/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3069 - precision_score: 0.8815 - recall_score: 0.8815 - f1_score: 0.8815 - val_loss: 0.3370 - val_precision_score: 0.8583 - val_recall_score: 0.8583 - val_f1_score: 0.8583
# Epoch 31/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.2975 - precision_score: 0.8659 - recall_score: 0.8659 - f1_score: 0.8659 - val_loss: 0.2793 - val_precision_score: 0.9021 - val_recall_score: 0.9021 - val_f1_score: 0.9021
# Epoch 32/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.3460 - precision_score: 0.8958 - recall_score: 0.8958 - f1_score: 0.8958 - val_loss: 0.3403 - val_precision_score: 0.8479 - val_recall_score: 0.8479 - val_f1_score: 0.8479
# Epoch 33/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3905 - precision_score: 0.8315 - recall_score: 0.8315 - f1_score: 0.8315 - val_loss: 0.2934 - val_precision_score: 0.8708 - val_recall_score: 0.8708 - val_f1_score: 0.8708
# Epoch 34/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.4439 - precision_score: 0.7761 - recall_score: 0.7761 - f1_score: 0.7761 - val_loss: 0.3383 - val_precision_score: 0.8417 - val_recall_score: 0.8417 - val_f1_score: 0.8417
# Epoch 35/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3462 - precision_score: 0.8450 - recall_score: 0.8450 - f1_score: 0.8450 - val_loss: 0.2968 - val_precision_score: 0.8687 - val_recall_score: 0.8687 - val_f1_score: 0.8687
# Epoch 36/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.4174 - precision_score: 0.8114 - recall_score: 0.8114 - f1_score: 0.8114 - val_loss: 0.4098 - val_precision_score: 0.7875 - val_recall_score: 0.7875 - val_f1_score: 0.7875
# Epoch 37/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.4853 - precision_score: 0.7516 - recall_score: 0.7516 - f1_score: 0.7516 - val_loss: 0.4277 - val_precision_score: 0.7917 - val_recall_score: 0.7917 - val_f1_score: 0.7917
# Epoch 38/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.4305 - precision_score: 0.7754 - recall_score: 0.7754 - f1_score: 0.7754 - val_loss: 0.3375 - val_precision_score: 0.8771 - val_recall_score: 0.8771 - val_f1_score: 0.8771
# Epoch 39/100
# 5/5 [==============================] - 27s 7s/step - loss: 0.3011 - precision_score: 0.8204 - recall_score: 0.8204 - f1_score: 0.8204 - val_loss: 0.3094 - val_precision_score: 0.8438 - val_recall_score: 0.8438 - val_f1_score: 0.8437
# Epoch 40/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3257 - precision_score: 0.8378 - recall_score: 0.8378 - f1_score: 0.8378 - val_loss: 0.3118 - val_precision_score: 0.8583 - val_recall_score: 0.8583 - val_f1_score: 0.8583
# Epoch 41/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2642 - precision_score: 0.8917 - recall_score: 0.8917 - f1_score: 0.8917 - val_loss: 0.2597 - val_precision_score: 0.8938 - val_recall_score: 0.8938 - val_f1_score: 0.8938
# Epoch 42/100
# 5/5 [==============================] - 27s 7s/step - loss: 0.5855 - precision_score: 0.7145 - recall_score: 0.7145 - f1_score: 0.7145 - val_loss: 0.2827 - val_precision_score: 0.8833 - val_recall_score: 0.8833 - val_f1_score: 0.8833
# Epoch 43/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3232 - precision_score: 0.8597 - recall_score: 0.8597 - f1_score: 0.8597 - val_loss: 0.2885 - val_precision_score: 0.8729 - val_recall_score: 0.8729 - val_f1_score: 0.8729
# Epoch 44/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3392 - precision_score: 0.8629 - recall_score: 0.8629 - f1_score: 0.8629 - val_loss: 0.2856 - val_precision_score: 0.8875 - val_recall_score: 0.8875 - val_f1_score: 0.8875
# Epoch 45/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.4364 - precision_score: 0.7900 - recall_score: 0.7900 - f1_score: 0.7900 - val_loss: 0.2853 - val_precision_score: 0.8833 - val_recall_score: 0.8833 - val_f1_score: 0.8833
# Epoch 46/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.3141 - precision_score: 0.8498 - recall_score: 0.8498 - f1_score: 0.8498 - val_loss: 0.2797 - val_precision_score: 0.9083 - val_recall_score: 0.9083 - val_f1_score: 0.9083
# Epoch 47/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2429 - precision_score: 0.9088 - recall_score: 0.9088 - f1_score: 0.9088 - val_loss: 0.3033 - val_precision_score: 0.8854 - val_recall_score: 0.8854 - val_f1_score: 0.8854
# Epoch 48/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3128 - precision_score: 0.8839 - recall_score: 0.8839 - f1_score: 0.8839 - val_loss: 0.2438 - val_precision_score: 0.9250 - val_recall_score: 0.9250 - val_f1_score: 0.9250
# Epoch 49/100
# 5/5 [==============================] - 27s 7s/step - loss: 0.3348 - precision_score: 0.8644 - recall_score: 0.8644 - f1_score: 0.8644 - val_loss: 0.2694 - val_precision_score: 0.8583 - val_recall_score: 0.8583 - val_f1_score: 0.8583
# Epoch 50/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.2620 - precision_score: 0.8852 - recall_score: 0.8852 - f1_score: 0.8852 - val_loss: 0.2638 - val_precision_score: 0.9021 - val_recall_score: 0.9021 - val_f1_score: 0.9021
# Epoch 51/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.3142 - precision_score: 0.8705 - recall_score: 0.8705 - f1_score: 0.8705 - val_loss: 0.2208 - val_precision_score: 0.9083 - val_recall_score: 0.9083 - val_f1_score: 0.9083
# Epoch 52/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.2569 - precision_score: 0.8584 - recall_score: 0.8584 - f1_score: 0.8584 - val_loss: 0.2938 - val_precision_score: 0.8833 - val_recall_score: 0.8833 - val_f1_score: 0.8833
# Epoch 53/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2525 - precision_score: 0.8866 - recall_score: 0.8866 - f1_score: 0.8866 - val_loss: 0.2441 - val_precision_score: 0.8979 - val_recall_score: 0.8979 - val_f1_score: 0.8979
# Epoch 54/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.2653 - precision_score: 0.8947 - recall_score: 0.8947 - f1_score: 0.8947 - val_loss: 0.2782 - val_precision_score: 0.8833 - val_recall_score: 0.8833 - val_f1_score: 0.8833
# Epoch 55/100
# 5/5 [==============================] - 27s 7s/step - loss: 0.2374 - precision_score: 0.9041 - recall_score: 0.9041 - f1_score: 0.9041 - val_loss: 0.2692 - val_precision_score: 0.8813 - val_recall_score: 0.8813 - val_f1_score: 0.8813
# Epoch 56/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3019 - precision_score: 0.8529 - recall_score: 0.8529 - f1_score: 0.8529 - val_loss: 0.2320 - val_precision_score: 0.8813 - val_recall_score: 0.8813 - val_f1_score: 0.8813
# Epoch 57/100
# 5/5 [==============================] - 27s 7s/step - loss: 0.2458 - precision_score: 0.9263 - recall_score: 0.9263 - f1_score: 0.9263 - val_loss: 0.2916 - val_precision_score: 0.9000 - val_recall_score: 0.9000 - val_f1_score: 0.9000
# Epoch 58/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.2401 - precision_score: 0.8957 - recall_score: 0.8957 - f1_score: 0.8957 - val_loss: 0.2134 - val_precision_score: 0.9312 - val_recall_score: 0.9312 - val_f1_score: 0.9312
# Epoch 59/100
# 5/5 [==============================] - 28s 6s/step - loss: 0.4076 - precision_score: 0.8510 - recall_score: 0.8510 - f1_score: 0.8510 - val_loss: 0.2898 - val_precision_score: 0.8667 - val_recall_score: 0.8667 - val_f1_score: 0.8667
# Epoch 60/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2543 - precision_score: 0.8853 - recall_score: 0.8853 - f1_score: 0.8853 - val_loss: 0.2951 - val_precision_score: 0.8938 - val_recall_score: 0.8938 - val_f1_score: 0.8938
# Epoch 61/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.2166 - precision_score: 0.8964 - recall_score: 0.8964 - f1_score: 0.8964 - val_loss: 0.2797 - val_precision_score: 0.8833 - val_recall_score: 0.8833 - val_f1_score: 0.8833
# Epoch 62/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3301 - precision_score: 0.8722 - recall_score: 0.8722 - f1_score: 0.8722 - val_loss: 0.2926 - val_precision_score: 0.8438 - val_recall_score: 0.8438 - val_f1_score: 0.8437
# Epoch 63/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.2493 - precision_score: 0.8645 - recall_score: 0.8645 - f1_score: 0.8645 - val_loss: 0.2569 - val_precision_score: 0.8667 - val_recall_score: 0.8667 - val_f1_score: 0.8667
# Epoch 64/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3188 - precision_score: 0.8452 - recall_score: 0.8452 - f1_score: 0.8452 - val_loss: 0.2312 - val_precision_score: 0.8979 - val_recall_score: 0.8979 - val_f1_score: 0.8979
# Epoch 65/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.2367 - precision_score: 0.9371 - recall_score: 0.9371 - f1_score: 0.9371 - val_loss: 0.2816 - val_precision_score: 0.8687 - val_recall_score: 0.8687 - val_f1_score: 0.8687
# Epoch 66/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3347 - precision_score: 0.8572 - recall_score: 0.8572 - f1_score: 0.8572 - val_loss: 0.2892 - val_precision_score: 0.8896 - val_recall_score: 0.8896 - val_f1_score: 0.8896
# Epoch 67/100
# 5/5 [==============================] - 29s 7s/step - loss: 0.1939 - precision_score: 0.9299 - recall_score: 0.9299 - f1_score: 0.9299 - val_loss: 0.2803 - val_precision_score: 0.8750 - val_recall_score: 0.8750 - val_f1_score: 0.8750
# Epoch 68/100
# 5/5 [==============================] - 29s 7s/step - loss: 0.2844 - precision_score: 0.8730 - recall_score: 0.8730 - f1_score: 0.8730 - val_loss: 0.2626 - val_precision_score: 0.8667 - val_recall_score: 0.8667 - val_f1_score: 0.8667
# Epoch 69/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2712 - precision_score: 0.8781 - recall_score: 0.8781 - f1_score: 0.8781 - val_loss: 0.2702 - val_precision_score: 0.8833 - val_recall_score: 0.8833 - val_f1_score: 0.8833
# Epoch 70/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3796 - precision_score: 0.8303 - recall_score: 0.8303 - f1_score: 0.8303 - val_loss: 0.2621 - val_precision_score: 0.9187 - val_recall_score: 0.9187 - val_f1_score: 0.9187
# Epoch 71/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2190 - precision_score: 0.9216 - recall_score: 0.9216 - f1_score: 0.9216 - val_loss: 0.3373 - val_precision_score: 0.7854 - val_recall_score: 0.7854 - val_f1_score: 0.7854
# Epoch 72/100
# 5/5 [==============================] - 27s 7s/step - loss: 0.2518 - precision_score: 0.9306 - recall_score: 0.9306 - f1_score: 0.9306 - val_loss: 0.2761 - val_precision_score: 0.8896 - val_recall_score: 0.8896 - val_f1_score: 0.8896
# Epoch 73/100
# 5/5 [==============================] - 29s 7s/step - loss: 0.3099 - precision_score: 0.8511 - recall_score: 0.8511 - f1_score: 0.8511 - val_loss: 0.2353 - val_precision_score: 0.9083 - val_recall_score: 0.9083 - val_f1_score: 0.9083
# Epoch 74/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.1970 - precision_score: 0.9379 - recall_score: 0.9379 - f1_score: 0.9379 - val_loss: 0.2380 - val_precision_score: 0.9146 - val_recall_score: 0.9146 - val_f1_score: 0.9146
# Epoch 75/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.2747 - precision_score: 0.8793 - recall_score: 0.8793 - f1_score: 0.8793 - val_loss: 0.2645 - val_precision_score: 0.9083 - val_recall_score: 0.9083 - val_f1_score: 0.9083
# Epoch 76/100
# 5/5 [==============================] - 29s 7s/step - loss: 0.2473 - precision_score: 0.8937 - recall_score: 0.8937 - f1_score: 0.8937 - val_loss: 0.2722 - val_precision_score: 0.9062 - val_recall_score: 0.9062 - val_f1_score: 0.9062
# Epoch 77/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.2444 - precision_score: 0.9081 - recall_score: 0.9081 - f1_score: 0.9081 - val_loss: 0.3035 - val_precision_score: 0.9000 - val_recall_score: 0.9000 - val_f1_score: 0.9000
# Epoch 78/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.2429 - precision_score: 0.9153 - recall_score: 0.9153 - f1_score: 0.9153 - val_loss: 0.2919 - val_precision_score: 0.8896 - val_recall_score: 0.8896 - val_f1_score: 0.8896
# Epoch 79/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3175 - precision_score: 0.8823 - recall_score: 0.8823 - f1_score: 0.8823 - val_loss: 0.2883 - val_precision_score: 0.9208 - val_recall_score: 0.9208 - val_f1_score: 0.9208
# Epoch 80/100
# 5/5 [==============================] - 29s 7s/step - loss: 0.2948 - precision_score: 0.8891 - recall_score: 0.8891 - f1_score: 0.8891 - val_loss: 0.2739 - val_precision_score: 0.9042 - val_recall_score: 0.9042 - val_f1_score: 0.9042
# Epoch 81/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2381 - precision_score: 0.9030 - recall_score: 0.9030 - f1_score: 0.9030 - val_loss: 0.2566 - val_precision_score: 0.9146 - val_recall_score: 0.9146 - val_f1_score: 0.9146
# Epoch 82/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.3434 - precision_score: 0.8568 - recall_score: 0.8568 - f1_score: 0.8568 - val_loss: 0.2722 - val_precision_score: 0.8771 - val_recall_score: 0.8771 - val_f1_score: 0.8771
# Epoch 83/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2475 - precision_score: 0.9090 - recall_score: 0.9090 - f1_score: 0.9090 - val_loss: 0.3764 - val_precision_score: 0.8417 - val_recall_score: 0.8417 - val_f1_score: 0.8417
# Epoch 84/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2720 - precision_score: 0.8569 - recall_score: 0.8569 - f1_score: 0.8569 - val_loss: 0.3262 - val_precision_score: 0.8667 - val_recall_score: 0.8667 - val_f1_score: 0.8667
# Epoch 85/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.3102 - precision_score: 0.8959 - recall_score: 0.8959 - f1_score: 0.8959 - val_loss: 0.3433 - val_precision_score: 0.8396 - val_recall_score: 0.8396 - val_f1_score: 0.8396
# Epoch 86/100
# 5/5 [==============================] - 30s 7s/step - loss: 0.2620 - precision_score: 0.9083 - recall_score: 0.9083 - f1_score: 0.9083 - val_loss: 0.2471 - val_precision_score: 0.9083 - val_recall_score: 0.9083 - val_f1_score: 0.9083
# Epoch 87/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.2296 - precision_score: 0.9320 - recall_score: 0.9320 - f1_score: 0.9320 - val_loss: 0.2862 - val_precision_score: 0.8375 - val_recall_score: 0.8375 - val_f1_score: 0.8375
# Epoch 88/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.1839 - precision_score: 0.9564 - recall_score: 0.9564 - f1_score: 0.9564 - val_loss: 0.2791 - val_precision_score: 0.8604 - val_recall_score: 0.8604 - val_f1_score: 0.8604
# Epoch 89/100
# 5/5 [==============================] - 29s 6s/step - loss: 0.2069 - precision_score: 0.9346 - recall_score: 0.9346 - f1_score: 0.9346 - val_loss: 0.2523 - val_precision_score: 0.8625 - val_recall_score: 0.8625 - val_f1_score: 0.8625
# Epoch 90/100
# 5/5 [==============================] - 29s 6s/step - loss: 0.2070 - precision_score: 0.9010 - recall_score: 0.9010 - f1_score: 0.9010 - val_loss: 0.2635 - val_precision_score: 0.8750 - val_recall_score: 0.8750 - val_f1_score: 0.8750
# Epoch 91/100
# 5/5 [==============================] - 29s 6s/step - loss: 0.1951 - precision_score: 0.9280 - recall_score: 0.9280 - f1_score: 0.9280 - val_loss: 0.2403 - val_precision_score: 0.8854 - val_recall_score: 0.8854 - val_f1_score: 0.8854
# Epoch 92/100
# 5/5 [==============================] - 29s 6s/step - loss: 0.2304 - precision_score: 0.9286 - recall_score: 0.9286 - f1_score: 0.9286 - val_loss: 0.2849 - val_precision_score: 0.8938 - val_recall_score: 0.8938 - val_f1_score: 0.8938
# Epoch 93/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.1975 - precision_score: 0.8920 - recall_score: 0.8920 - f1_score: 0.8920 - val_loss: 0.2994 - val_precision_score: 0.9021 - val_recall_score: 0.9021 - val_f1_score: 0.9021
# Epoch 94/100
# 5/5 [==============================] - 29s 6s/step - loss: 0.2898 - precision_score: 0.8556 - recall_score: 0.8556 - f1_score: 0.8556 - val_loss: 0.2222 - val_precision_score: 0.9187 - val_recall_score: 0.9187 - val_f1_score: 0.9187
# Epoch 95/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.2143 - precision_score: 0.9385 - recall_score: 0.9385 - f1_score: 0.9385 - val_loss: 0.2157 - val_precision_score: 0.9312 - val_recall_score: 0.9312 - val_f1_score: 0.9312
# Epoch 96/100
# 5/5 [==============================] - 29s 6s/step - loss: 0.3082 - precision_score: 0.8544 - recall_score: 0.8544 - f1_score: 0.8544 - val_loss: 0.2802 - val_precision_score: 0.8792 - val_recall_score: 0.8792 - val_f1_score: 0.8792
# Epoch 97/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.2259 - precision_score: 0.9493 - recall_score: 0.9493 - f1_score: 0.9493 - val_loss: 0.2204 - val_precision_score: 0.9333 - val_recall_score: 0.9333 - val_f1_score: 0.9333
# Epoch 98/100
# 5/5 [==============================] - 29s 6s/step - loss: 0.2947 - precision_score: 0.8874 - recall_score: 0.8874 - f1_score: 0.8874 - val_loss: 0.2106 - val_precision_score: 0.8938 - val_recall_score: 0.8938 - val_f1_score: 0.8937
# Epoch 99/100
# 5/5 [==============================] - 29s 6s/step - loss: 0.2691 - precision_score: 0.8759 - recall_score: 0.8759 - f1_score: 0.8759 - val_loss: 0.2584 - val_precision_score: 0.8917 - val_recall_score: 0.8917 - val_f1_score: 0.8917
# Epoch 100/100
# 5/5 [==============================] - 27s 6s/step - loss: 0.2188 - precision_score: 0.8818 - recall_score: 0.8818 - f1_score: 0.8818 - val_loss: 0.2632 - val_precision_score: 0.8896 - val_recall_score: 0.8896 - val_f1_score: 0.8896

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**: Todos obtiveram o mesmo valor de 88,96%

# %% [markdown]
# ## 4.6 Compartivo de arquiteturas
#
# Preencha a tabela abaixo com os valores dos indicadores de performance apresentados.
#
# _O cálculo do F1-Score é dado por 2 * (Precisão * Sensibilidade) / (Precisão + Sensibilidade)._

# %% [markdown]
# | Modelo   | Precisão (*Precision*) | Sensibilidade (*Recall*) | F1-Score |
# |----------|----------|---------------|----------|
# | ResNet50 | 91,87 %     | 91,87 %          | 91,87 %     |
# | VGG16    | 90,62 %     | 90,62 %          | 90,62 %     |
# | VGG19    | 88,96 %     | 88,96 %          | 88,96 %     |

# %% [markdown]
# ## 4.7 Conclusões
#
# Analise os resultados da tabela de indicadores do comparativo de arquiteturas e explique os principais motivos pelos quais cada modelo obteve cada resultado.

# %% [markdown]
# **Respota**:

# %% [markdown]
# ## 4.8 Abordagem Extra
#
# Considerando os outros classificadores, escolha outro que ainda não foi utilizado, implemente abaixo. Ao final compare os resultados e explique os resultados.
#
# _Não se esquece de utilizar as importações adequadas para cada modelo.
# A forma de implementação deve respeitar as mesmas condições como valor de split e quantidade de imagens para poder comparar os modelos._

# %%
#IMPLEMENTE

# %% [markdown]
# ### 4.8.1 Conclusões sobre a abordagem extra
#
# Como seu modelo performou em comparação com os demais modelos anteriores? Justifique sua resposta levando em consideração a arquitetura respectiva.

# %% [markdown]
# **Resposta**:
