# %% [markdown]
# # MBA FIAP Inteligência Artificial & Machine Learning
#
# ## Visão Computacional: Análise de Imagens Médicas
#
# ## 1. Introdução
#
# As tecnologias de imagens médicas estão cada vez mais integradas aos sitemas de visão computacional, incluindo as imagens de raio-x.
#
# Modelos de equipamentos modernos geram imagens digitais deste tipo de exame, proporcionando análises mais completas e menos _ad-hoc_, com isso algumas pré-análises podem ser realizadas por aplicações baseadas em inteligência artificial para confirmar ou sugerir diagnósticos ao profissional responsável pelo exame.
#
# No campo dos diagósticos por raios-x, a pnenumonia é uma das enfermidades onde seu uso é um dos mais aplicados para determinar o curso de tratamento.
#
# <p align="center">
#     <img src="imagens/NORMAL2-IM-1422-0001.jpeg">
# </p>
#
# ## 2. Instruções
#
# Este projeto final tem como objetivo explorar os conhecimentos adquiridos nas aulas práticas.
#
# Por meio de uma trilha guiada, iremos constuir um modelo que seja capaz de classificar imagens de raio-x para determinar se a determinada pessoa está com alguma condição que necessita maiores cuidados.
#
# De acordo com as imagens disponíveis para o treinamento e validação, será de critério do grupo selecionar as quantidades ideais ou até mesmo pré-processar as imagens para obter o melhor resultado, nos principais indicadores de performance, como precisão, sensibilidade e pontuação F1.
#
# Este projeto poderá ser feita por grupos de até 4 pessoas.
# Caso este projeto seja substitutivo, deverá ser realizado por apenas uma pessoa.
#
# | Nome dos Integrantes     | RM            | Turma |
# | :----------------------- | :------------- | :-----: |
# | Integrante 1             | RM 12345      | `1IA` |
# | Integrante 2             | RM 12345      | `1IA` |
# | Integrante 3             | RM 12345      | `1IA` |
# | Integrante 4             | RM 12345      | `1IA` |
#
# Por ser um projeto guiado, fique atento quando houver as marcações **Implementação** indica que é necessário realizar alguma implementação em Python no bloco a seguir onde há a inscrição ```##IMPLEMENTAR``` e **Resposta** indica que é esperado uma resposta objetiva relacionado a algum questionamento.
#
# **Cada grupo pode utilizar nas respostas objetivas quaisquer itens necessários que enriqueçam seu ponto vista, como gráficos, fotos e, até mesmo, trechos de código-fonte.**
#
# Pode-se utilizar quantos blocos forem necessários para realizar determinadas implementações ou utilizá-las para justificar as respostas. Não é obrigatório utilizar somente o bloco indicado.
#
# Ao final não se esqueça de subir os arquivos do projeto nas contas do GitHub de cada membro, ou subir na do representante do grupo e os membros realizarem o fork do projeto.
#
# A avaliação terá mais ênfase nos seguintes tópicos de desenvolvimento do projeto:
#
# 1. __Pré-Processamento__
# 2. __Classificação__
# 3. __Performance__
# 4. __Conclusões Finais__

# %% [markdown]
# ## 3.1 Detalhe do problema: a pneunomia
#
# Fonte: [artigo](https://drauziovarella.uol.com.br/doencas-e-sintomas/pneumonia) do Dr. Drauzio Varella.
#
# Pneumonias são infecções que se instalam nos pulmões, órgãos duplos localizados um de cada lado da caixa torácica. Podem acometer a região dos alvéolos pulmonares onde desembocam as ramificações terminais dos brônquios e, às vezes, os interstícios (espaço entre um alvéolo e outro).
#
# Basicamente, pneumonia é provocada pela penetração de um agente infeccioso ou irritante (bactérias, vírus, fungos e por reações alérgicas) no espaço alveolar, onde ocorre a troca gasosa. Esse local deve estar sempre muito limpo, livre de substâncias que possam impedir o contato do ar com o sangue.
#
# Exame clínico, auscultação dos pulmões e radiografias de tórax são recursos essenciais para o diagnóstico de pneumonia.
#
# <p align="center">
#     <img src="imagens/pneumonia.jpeg">
# </p>

# %% [markdown]
# ## 3.2 Diagnóstico por raio-x

# %% [markdown]
# O exame de raio-x traz diferenças em cada tipo de diagnóstico, sendo considerado os seguintes grupos de análise: **normal** (ou controle) onde não há nenhuma condição de infeção, **bacterial pneumonia** (pneumonia bacteriana) que representa a condição de infecção bacteriana e **viral pneumonia** que indica a condição de infecção vira.

# %% [markdown]
# <p align="center">
# <img src="imagens/raiox.png" height="60%" width="60%">
# </p>

# %% [markdown]
# As imagens de controle não são mais brancas ao centro que é onde fica o coração. Já nas imagens com pneumonia é possível notar regiões brancas ao redor dos pulmões, que é como o exame identifica as secreções responsáveis pela infeçcão.
#
# Quando mais regiões brancas ao redor do pulmão mais severa é a inflamação e menos se observa dos detalhes dos pulmões, ficando um pouco esmaecido diante desta condição.

# %% [markdown]
# ## 4.1 Problema
#
# Construir um classificador utilizando _transfer learning_ para identificar as seguintes classes: **controle**, **pneumonia bacteriana** e **pneumonia viral**.
#
# Para construir este classificador, utilize o dataset do [Kaggle Chest Ray Pneumonia](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) e organize os dados de forma a separar em cada uma das classes que já estão definidas no diretório ```raiox```, sendo ```controle``` para as imagens normais (sem inflamação), ```bacteria``` para as imagens de pneumonia bacteriana e ```viral``` para as imagens de pneumonia viral.
#
# Determine a quantidade de imagens a serem treinadas e validadas. Utiliza pelo menos, 100 imagens para cada classe.
#
# Compare os resultados com pelo menos 3 classificadores, obtendo os valores de **precisão (precision)**, **sensibilidade (recall)** e **pontuação F1 (F1 Score)**. No guia abaixo, foi indicado os seguintes modelos: ResNet50, VGG16 e VGG19.
#
# >Importante: a escolha do número de imagens devem ser o suficiente para alcançar o valor de **precisão** mínima de 70%.
#
# A construção do modelo será utilizada o framework Keras.

# %% [markdown]
# **Pergunta**: Qual o número de imagens que foram selecionadas para cada classe?

# %% [markdown]
# **Resposta**:

# %% [markdown]
# ## 4.2 Componentes obrigatórios
#
# Este projeto requer a instalação dos seguintes componentes, via ```conda install```:
#
# * Keras
# * Tensorflow
# * Pillow
# * Matplotlib

# %%
# !conda install keras
import os

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %matplotlib inline

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import ResNet50
from keras.applications import VGG16, VGG19
from keras.applications import Xception
from keras.applications.xception import preprocess_input
from keras.applications.resnet50 import preprocess_input
from keras.applications.vgg16 import preprocess_input
from keras import Model, layers
from keras.models import load_model, model_from_json

import keras.backend as K
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Building graph of deps:   0%|          | 0/315 [00:00<?, ?it/s]
# Examining pandas:   0%|          | 0/315 [00:00<?, ?it/s]
# Examining bleach:   0%|          | 1/315 [00:01<08:56,  1.71s/it]
# Examining bleach:   1%|          | 2/315 [00:01<04:27,  1.17it/s]
# Examining vc:   1%|          | 2/315 [00:02<04:27,  1.17it/s]
# Examining vc:   1%|          | 3/315 [00:02<03:42,  1.40it/s]
# Examining python-jsonrpc-server:   1%|          | 3/315 [00:02<03:42,  1.40it/s]
# Examining pyyaml:   1%|1         | 4/315 [00:02<03:41,  1.40it/s]
# Examining bcrypt:   2%|1         | 5/315 [00:02<03:40,  1.40it/s]
# Examining pyopenssl:   2%|1         | 6/315 [00:02<03:39,  1.40it/s]
# Examining pyopenssl:   2%|2         | 7/315 [00:02<02:39,  1.93it/s]
# Examining pathtools:   2%|2         | 7/315 [00:02<02:39,  1.93it/s]
# Examining pathtools:   3%|2         | 8/315 [00:02<02:16,  2.25it/s]
# Examining qtpy:   3%|2         | 8/315 [00:02<02:16,  2.25it/s]
# Examining chardet:   3%|2         | 9/315 [00:02<02:15,  2.25it/s]
# Examining jupyter_core:   3%|3         | 10/315 [00:02<02:15,  2.25it/s]
# Examining sympy:   3%|3         | 11/315 [00:02<02:14,  2.25it/s]
# Examining sympy:   4%|3         | 12/315 [00:02<01:37,  3.11it/s]
# Examining more-itertools:   4%|3         | 12/315 [00:02<01:37,  3.11it/s]
# Examining pluggy:   4%|4         | 13/315 [00:03<01:37,  3.11it/s]
# Examining pluggy:   4%|4         | 14/315 [00:03<01:19,  3.81it/s]
# Examining setuptools:   4%|4         | 14/315 [00:03<01:19,  3.81it/s]
# Examining dask-core:   5%|4         | 15/315 [00:03<01:18,  3.81it/s]
# Examining dask-core:   5%|5         | 16/315 [00:03<01:18,  3.81it/s]
# Examining urllib3:   5%|5         | 16/315 [00:03<01:18,  3.81it/s]
# Examining urllib3:   5%|5         | 17/315 [00:03<01:32,  3.24it/s]
# Examining clyent:   5%|5         | 17/315 [00:04<01:32,  3.24it/s]
# Examining clyent:   6%|5         | 18/315 [00:04<02:25,  2.05it/s]
# Examining sqlalchemy:   6%|5         | 18/315 [00:04<02:25,  2.05it/s]
# Examining sqlalchemy:   6%|6         | 19/315 [00:04<01:51,  2.65it/s]
# Examining yaml:   6%|6         | 19/315 [00:05<01:51,  2.65it/s]
# Examining yaml:   6%|6         | 20/315 [00:05<01:35,  3.10it/s]
# Examining anaconda-client:   6%|6         | 20/315 [00:05<01:35,  3.10it/s]
# Examining jupyterlab:   7%|6         | 21/315 [00:05<01:34,  3.10it/s]
# Examining jupyterlab:   7%|6         | 22/315 [00:05<01:34,  3.12it/s]
# Examining blas:   7%|6         | 22/315 [00:08<01:34,  3.12it/s]
# Examining blas:   7%|7         | 23/315 [00:08<05:21,  1.10s/it]
# Examining cloudpickle:   7%|7         | 23/315 [00:08<05:21,  1.10s/it]
# Examining xlrd:   8%|7         | 24/315 [00:08<05:20,  1.10s/it]
# Examining xlrd:   8%|7         | 25/315 [00:08<03:48,  1.27it/s]
# Examining winpty:   8%|7         | 25/315 [00:08<03:48,  1.27it/s]
# Examining pyqt:   8%|8         | 26/315 [00:08<03:47,  1.27it/s]
# Examining py:   9%|8         | 27/315 [00:08<03:47,  1.27it/s]
# Examining win_unicode_console:   9%|8         | 28/315 [00:08<03:46,  1.27it/s]
# Examining win_unicode_console:   9%|9         | 29/315 [00:08<02:40,  1.78it/s]
# Examining dask:   9%|9         | 29/315 [00:08<02:40,  1.78it/s]
# Examining diff-match-patch:  10%|9         | 30/315 [00:19<02:40,  1.78it/s]
# Examining diff-match-patch:  10%|9         | 31/315 [00:19<09:18,  1.97s/it]
# Examining _ipyw_jlab_nb_ext_conf:  10%|9         | 31/315 [00:19<09:18,  1.97s/it]
# Examining requests:  10%|#         | 32/315 [00:19<09:16,  1.97s/it]
# Examining requests:  10%|#         | 33/315 [00:19<06:34,  1.40s/it]
# Examining conda-env:  10%|#         | 33/315 [00:19<06:34,  1.40s/it]
# Examining conda-env:  11%|#         | 34/315 [00:19<04:49,  1.03s/it]
# Examining pkginfo:  11%|#         | 34/315 [00:19<04:49,  1.03s/it]
# Examining opencv:  11%|#1        | 35/315 [00:19<04:48,  1.03s/it]
# Examining singledispatch:  11%|#1        | 36/315 [00:19<04:47,  1.03s/it]
# Examining @/win-64::__archspec==1=x86_64:  12%|#1        | 37/315 [00:19<04:46,  1.03s/it]
# Examining @/win-64::__archspec==1=x86_64:  12%|#2        | 38/315 [00:19<03:22,  1.37it/s]
# Examining zope.interface:  12%|#2        | 38/315 [00:19<03:22,  1.37it/s]
# Examining alabaster:  12%|#2        | 39/315 [00:20<03:21,  1.37it/s]
# Examining alabaster:  13%|#2        | 40/315 [00:20<02:29,  1.84it/s]
# Examining toml:  13%|#2        | 40/315 [00:20<02:29,  1.84it/s]
# Examining xz:  13%|#3        | 41/315 [00:20<02:28,  1.84it/s]
# Examining @/win-64::__win==0=0:  13%|#3        | 42/315 [00:20<02:28,  1.84it/s]
# Examining pywin32:  14%|#3        | 43/315 [00:20<02:27,  1.84it/s]
# Examining sortedcollections:  14%|#3        | 44/315 [00:20<02:27,  1.84it/s]
# Examining filelock:  14%|#4        | 45/315 [00:20<02:26,  1.84it/s]
# Examining filelock:  15%|#4        | 46/315 [00:20<01:43,  2.59it/s]
# Examining unicodecsv:  15%|#4        | 46/315 [00:20<01:43,  2.59it/s]
# Examining pip:  15%|#4        | 47/315 [00:20<01:43,  2.59it/s]
# Examining iniconfig:  15%|#5        | 48/315 [00:21<01:43,  2.59it/s]
# Examining iniconfig:  16%|#5        | 49/315 [00:21<01:46,  2.49it/s]
# Examining libarchive:  16%|#5        | 49/315 [00:21<01:46,  2.49it/s]
# Examining scikit-image:  16%|#5        | 50/315 [00:21<01:46,  2.49it/s]
# Examining importlib_metadata:  16%|#6        | 51/315 [00:23<01:46,  2.49it/s]
# Examining importlib_metadata:  17%|#6        | 52/315 [00:23<02:07,  2.07it/s]
# Examining mistune:  17%|#6        | 52/315 [00:23<02:07,  2.07it/s]
# Examining pathlib2:  17%|#6        | 53/315 [00:23<02:06,  2.07it/s]
# Examining ujson:  17%|#7        | 54/315 [00:23<02:06,  2.07it/s]
# Examining ujson:  17%|#7        | 55/315 [00:23<01:31,  2.85it/s]
# Examining mpmath:  17%|#7        | 55/315 [00:23<01:31,  2.85it/s]
# Examining pyparsing:  18%|#7        | 56/315 [00:23<01:30,  2.85it/s]
# Examining pywin32-ctypes:  18%|#8        | 57/315 [00:23<01:30,  2.85it/s]
# Examining pywin32-ctypes:  18%|#8        | 58/315 [00:23<01:05,  3.90it/s]
# Examining fsspec:  18%|#8        | 58/315 [00:23<01:05,  3.90it/s]
# Examining pickleshare:  19%|#8        | 59/315 [00:23<01:05,  3.90it/s]
# Examining mkl_fft:  19%|#9        | 60/315 [00:23<01:05,  3.90it/s]
# Examining sphinxcontrib-serializinghtml:  19%|#9        | 61/315 [00:25<01:05,  3.90it/s]
# Examining sphinxcontrib-serializinghtml:  20%|#9        | 62/315 [00:25<01:08,  3.70it/s]
# Examining decorator:  20%|#9        | 62/315 [00:25<01:08,  3.70it/s]
# Examining numba:  20%|##        | 63/315 [00:25<01:08,  3.70it/s]
# Examining wcwidth:  20%|##        | 64/315 [00:26<01:07,  3.70it/s]
# Examining wcwidth:  21%|##        | 65/315 [00:26<01:35,  2.60it/s]
# Examining wheel:  21%|##        | 65/315 [00:27<01:35,  2.60it/s]
/s]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-33bc12223561> in <module>
#       8 get_ipython().run_line_magic('matplotlib', 'inline')
#       9
# ---> 10 import keras
#      11 from keras.preprocessing.image import ImageDataGenerator
#      12 from keras.applications import ResNet50
#
# ModuleNotFoundError: No module named 'keras'
# Examining webencodings:  49%|####8     | 154/315 [00:42<00:20,  7.81it/s]
# Examining webencodings:  49%|####9     | 155/315 [00:42<00:16,  9.59it/s]
# Examining anaconda==2020.11:  49%|####9     | 155/315 [00:42<00:16,  9.59it/s]
# Examining msgpack-python:  50%|####9     | 156/315 [00:42<00:16,  9.59it/s]
# Examining flake8:  50%|####9     | 157/315 [00:42<00:16,  9.59it/s]
# Examining m2w64-gcc-libs:  50%|#####     | 158/315 [00:42<00:16,  9.59it/s]
# Examining m2w64-gcc-libs:  50%|#####     | 159/315 [00:42<00:16,  9.24it/s]
# Examining msys2-conda-epoch:  50%|#####     | 159/315 [00:42<00:16,  9.24it/s]
# Examining pyreadline:  51%|#####     | 160/315 [00:42<00:16,  9.24it/s]
# Examining nltk:  51%|#####1    | 161/315 [00:42<00:16,  9.24it/s]
# Examining send2trash:  51%|#####1    | 162/315 [00:43<00:16,  9.24it/s]
# Examining send2trash:  52%|#####1    | 163/315 [00:43<00:14, 10.66it/s]
# Examining libsodium:  52%|#####1    | 163/315 [00:43<00:14, 10.66it/s]
# Examining backports.functools_lru_cache:  52%|#####2    | 164/315 [00:43<00:14, 10.66it/s]
# Examining anaconda-navigator:  52%|#####2    | 165/315 [00:43<00:14, 10.66it/s]
# Examining anaconda-navigator:  53%|#####2    | 166/315 [00:43<00:11, 13.05it/s]
# Examining libxml2:  53%|#####2    | 166/315 [00:45<00:11, 13.05it/s]
# Examining mkl:  53%|#####3    | 167/315 [00:45<00:11, 13.05it/s]
# Examining mccabe:  53%|#####3    | 168/315 [00:45<00:11, 13.05it/s]
# Examining mccabe:  54%|#####3    | 169/315 [00:45<00:38,  3.83it/s]
# Examining libcurl:  54%|#####3    | 169/315 [00:45<00:38,  3.83it/s]
# Examining qtconsole:  54%|#####3    | 170/315 [00:45<00:37,  3.83it/s]
# Examining mkl_random:  54%|#####4    | 171/315 [00:45<00:37,  3.83it/s]
# Examining mkl_random:  55%|#####4    | 172/315 [00:45<00:34,  4.12it/s]
# Examining zstd:  55%|#####4    | 172/315 [00:46<00:34,  4.12it/s]
# Examining nest-asyncio:  55%|#####4    | 173/315 [00:46<00:34,  4.12it/s]
# Examining nest-asyncio:  55%|#####5    | 174/315 [00:46<00:33,  4.26it/s]
# Examining jupyter_console:  55%|#####5    | 174/315 [00:46<00:33,  4.26it/s]
# Examining entrypoints:  56%|#####5    | 175/315 [00:46<00:32,  4.26it/s]
# Examining entrypoints:  56%|#####5    | 176/315 [00:46<00:31,  4.43it/s]
# Examining jinja2:  56%|#####5    | 176/315 [00:46<00:31,  4.43it/s]
# Examining keras:  56%|#####6    | 177/315 [00:46<00:31,  4.43it/s]
# Examining keras:  57%|#####6    | 178/315 [00:46<00:26,  5.22it/s]
# Examining sphinxcontrib-applehelp:  57%|#####6    | 178/315 [00:47<00:26,  5.22it/s]
# Examining sphinxcontrib-applehelp:  57%|#####6    | 179/315 [00:47<00:38,  3.51it/s]
# Examining testpath:  57%|#####6    | 179/315 [00:47<00:38,  3.51it/s]
# Examining path:  57%|#####7    | 180/315 [00:47<00:38,  3.51it/s]
# Examining pillow:  57%|#####7    | 181/315 [00:47<00:38,  3.51it/s]
# Examining vs2015_runtime:  58%|#####7    | 182/315 [00:47<00:37,  3.51it/s]
# Examining vs2015_runtime:  58%|#####8    | 183/315 [00:47<00:29,  4.51it/s]
# Examining pexpect:  58%|#####8    | 183/315 [00:47<00:29,  4.51it/s]
# Examining matplotlib:  58%|#####8    | 184/315 [00:47<00:29,  4.51it/s]
# Examining brotlipy:  59%|#####8    | 185/315 [00:49<00:28,  4.51it/s]
# Examining brotlipy:  59%|#####9    | 186/315 [00:49<00:43,  2.94it/s]
# Examining cycler:  59%|#####9    | 186/315 [00:49<00:43,  2.94it/s]
# Examining numpy-base:  59%|#####9    | 187/315 [00:49<00:43,  2.94it/s]
# Examining jedi:  60%|#####9    | 188/315 [00:50<00:43,  2.94it/s]
# Examining jedi:  60%|######    | 189/315 [00:50<00:36,  3.44it/s]
# Examining ruamel_yaml:  60%|######    | 189/315 [00:50<00:36,  3.44it/s]
# Examining ruamel_yaml:  60%|######    | 190/315 [00:50<00:29,  4.26it/s]
# Examining prompt-toolkit:  60%|######    | 190/315 [00:50<00:29,  4.26it/s]
# Examining matplotlib-base:  61%|######    | 191/315 [00:50<00:29,  4.26it/s]
# Examining tblib:  61%|######    | 192/315 [00:51<00:28,  4.26it/s]
# Examining tblib:  61%|######1   | 193/315 [00:51<00:29,  4.18it/s]
# Examining libssh2:  61%|######1   | 193/315 [00:51<00:29,  4.18it/s]
# Examining nbclient:  62%|######1   | 194/315 [00:51<00:28,  4.18it/s]
# Examining ipython:  62%|######1   | 195/315 [00:51<00:28,  4.18it/s]
# Examining terminado:  62%|######2   | 196/315 [00:52<00:28,  4.18it/s]
# Examining terminado:  63%|######2   | 197/315 [00:52<00:29,  4.02it/s]
# Examining python-libarchive-c:  63%|######2   | 197/315 [00:52<00:29,  4.02it/s]
# Examining python-libarchive-c:  63%|######2   | 198/315 [00:52<00:24,  4.70it/s]
# Examining spyder:  63%|######2   | 198/315 [00:52<00:24,  4.70it/s]
# Examining spyder:  63%|######3   | 199/315 [00:52<00:23,  4.92it/s]
# Examining lzo:  63%|######3   | 199/315 [00:58<00:23,  4.92it/s]
# Examining lzo:  63%|######3   | 200/315 [00:58<03:50,  2.01s/it]
# Examining anaconda-project:  63%|######3   | 200/315 [00:58<03:50,  2.01s/it]
# Examining pyflakes:  64%|######3   | 201/315 [00:58<03:48,  2.01s/it]
# Examining pyflakes:  64%|######4   | 202/315 [00:58<02:42,  1.44s/it]
# Examining zict:  64%|######4   | 202/315 [00:58<02:42,  1.44s/it]
# Examining libpng:  64%|######4   | 203/315 [00:58<02:41,  1.44s/it]
# Examining pep8:  65%|######4   | 204/315 [00:58<02:39,  1.44s/it]
# Examining pep8:  65%|######5   | 205/315 [00:58<01:51,  1.02s/it]
# Examining argon2-cffi:  65%|######5   | 205/315 [00:58<01:51,  1.02s/it]
# Examining rtree:  65%|######5   | 206/315 [00:59<01:50,  1.02s/it]
# Examining h5py:  66%|######5   | 207/315 [00:59<01:49,  1.02s/it]
# Examining pytables:  66%|######6   | 208/315 [01:00<01:48,  1.02s/it]
# Examining pytables:  66%|######6   | 209/315 [01:00<01:24,  1.25it/s]
# Examining wrapt:  66%|######6   | 209/315 [01:01<01:24,  1.25it/s]
# Examining wrapt:  67%|######6   | 210/315 [01:01<01:38,  1.06it/s]
# Examining jupyter_client:  67%|######6   | 210/315 [01:01<01:38,  1.06it/s]
# Examining py-lief:  67%|######6   | 211/315 [01:01<01:37,  1.06it/s]
# Examining py-lief:  67%|######7   | 212/315 [01:01<01:13,  1.40it/s]
# Examining qdarkstyle:  67%|######7   | 212/315 [01:01<01:13,  1.40it/s]
# Examining click:  68%|######7   | 213/315 [01:01<01:13,  1.40it/s]
# Examining sphinxcontrib-jsmath:  68%|######7   | 214/315 [01:01<01:12,  1.40it/s]
# Examining astropy:  68%|######8   | 215/315 [01:01<01:11,  1.40it/s]
# Examining astropy:  69%|######8   | 216/315 [01:01<00:50,  1.96it/s]
# Examining scipy:  69%|######8   | 216/315 [01:05<00:50,  1.96it/s]
# Examining beautifulsoup4:  69%|######8   | 217/315 [01:06<00:49,  1.96it/s]
# Examining beautifulsoup4:  69%|######9   | 218/315 [01:06<01:40,  1.04s/it]
# Examining werkzeug:  69%|######9   | 218/315 [01:06<01:40,  1.04s/it]
# Examining attrs:  70%|######9   | 219/315 [01:06<01:39,  1.04s/it]
# Examining attrs:  70%|######9   | 220/315 [01:06<01:10,  1.34it/s]
# Examining sphinxcontrib-htmlhelp:  70%|######9   | 220/315 [01:06<01:10,  1.34it/s]
# Examining mock:  70%|#######   | 221/315 [01:06<01:09,  1.34it/s]
# Examining mock:  70%|#######   | 222/315 [01:06<00:49,  1.86it/s]
# Examining seaborn:  70%|#######   | 222/315 [01:06<00:49,  1.86it/s]
# Examining threadpoolctl:  71%|#######   | 223/315 [01:07<00:49,  1.86it/s]
# Examining threadpoolctl:  71%|#######1  | 224/315 [01:07<00:48,  1.87it/s]
# Examining glob2:  71%|#######1  | 224/315 [01:07<00:48,  1.87it/s]
# Examining blosc:  71%|#######1  | 225/315 [01:07<00:48,  1.87it/s]
# Examining xlwings:  72%|#######1  | 226/315 [01:07<00:47,  1.87it/s]
# Examining nose:  72%|#######2  | 227/315 [01:08<00:47,  1.87it/s]
# Examining nose:  72%|#######2  | 228/315 [01:08<00:34,  2.50it/s]
# Examining pandocfilters:  89%|########9 | 281/315 [01:39<00:11,  2.84it/s]
# Examining liblief:  89%|########9 | 281/315 [01:40<00:11,  2.84it/s]
# Examining ipywidgets:  90%|########9 | 282/315 [01:40<00:11,  2.84it/s]
# Examining comtypes:  90%|########9 | 283/315 [01:41<00:11,  2.84it/s]
# Examining comtypes:  90%|######### | 284/315 [01:41<00:11,  2.70it/s]
# Examining fastcache:  90%|######### | 284/315 [01:41<00:11,  2.70it/s]
# Examining m2w64-gcc-libgfortran:  90%|######### | 285/315 [01:41<00:11,  2.70it/s]
# Examining pygments:  91%|######### | 286/315 [01:41<00:10,  2.70it/s]
# Examining prometheus_client:  91%|#########1| 287/315 [01:41<00:10,  2.70it/s]
# Examining prometheus_client:  91%|#########1| 288/315 [01:41<00:07,  3.59it/s]
# Examining scikit-learn:  91%|#########1| 288/315 [01:41<00:07,  3.59it/s]
# Examining boto:  92%|#########1| 289/315 [01:43<00:07,  3.59it/s]
# Examining boto:  92%|#########2| 290/315 [01:43<00:11,  2.15it/s]
# Examining python_abi:  92%|#########2| 290/315 [01:43<00:11,  2.15it/s]
# Examining backports:  92%|#########2| 291/315 [01:43<00:11,  2.15it/s]
# Examining conda[version='>=4.10.1']:  93%|#########2| 292/315 [01:43<00:10,  2.15it/s]
# Examining partd:  93%|#########3| 293/315 [01:43<00:10,  2.15it/s]
# Examining partd:  93%|#########3| 294/315 [01:43<00:07,  2.97it/s]
# Examining locket:  93%|#########3| 294/315 [01:43<00:07,  2.97it/s]
# Examining libiconv:  94%|#########3| 295/315 [01:43<00:06,  2.97it/s]
# Examining wincertstore:  94%|#########3| 296/315 [01:43<00:06,  2.97it/s]
# Examining paramiko:  94%|#########4| 297/315 [01:43<00:06,  2.97it/s]
# Examining @/win-64::__cuda==11.3=0:  95%|#########4| 298/315 [01:43<00:05,  2.97it/s]
# Examining @/win-64::__cuda==11.3=0:  95%|#########4| 299/315 [01:43<00:04,  3.93it/s]
# Examining backports.shutil_get_terminal_size:  95%|#########4| 299/315 [01:43<00:04,  3.93it/s]
# Examining joblib:  95%|#########5| 300/315 [01:43<00:03,  3.93it/s]
# Examining numpydoc:  96%|#########5| 301/315 [01:43<00:03,  3.93it/s]
# Examining numpydoc:  96%|#########5| 302/315 [01:43<00:02,  5.23it/s]
# Examining cffi:  96%|#########5| 302/315 [01:44<00:02,  5.23it/s]
# Examining zeromq:  96%|#########6| 303/315 [01:44<00:02,  5.23it/s]
# Examining zeromq:  97%|#########6| 304/315 [01:44<00:02,  5.33it/s]
# Examining nbconvert:  97%|#########6| 304/315 [01:44<00:02,  5.33it/s]
# Examining pywavelets:  97%|#########6| 305/315 [01:44<00:01,  5.33it/s]
# Examining pywavelets:  97%|#########7| 306/315 [01:44<00:01,  4.72it/s]
# Examining defusedxml:  97%|#########7| 306/315 [01:45<00:01,  4.72it/s]
# Examining asn1crypto:  97%|#########7| 307/315 [01:45<00:01,  4.72it/s]
# Examining asn1crypto:  98%|#########7| 308/315 [01:45<00:01,  4.25it/s]
# Examining icu:  98%|#########7| 308/315 [01:45<00:01,  4.25it/s]
# Examining kiwisolver:  98%|#########8| 309/315 [01:45<00:01,  4.25it/s]
# Examining argh:  98%|#########8| 310/315 [01:45<00:01,  4.25it/s]
# Examining parso:  99%|#########8| 311/315 [01:45<00:00,  4.25it/s]
# Examining libopencv:  99%|#########9| 312/315 [01:45<00:00,  4.25it/s]
# Examining libopencv:  99%|#########9| 313/315 [01:45<00:00,  5.76it/s]
# Examining greenlet:  99%|#########9| 313/315 [01:45<00:00,  5.76it/s]
# Examining keyring: 100%|#########9| 314/315 [01:45<00:00,  5.76it/s]
#
#
# Determining conflicts:   0%|          | 0/315 [00:00<?, ?it/s]
# Examining conflict for pandas bkcharts dask statsmodels bokeh anaconda scikit-image seaborn:   0%|          | 0/315 [00:00<?, ?it/s]
# Examining conflict for patsy pandas dask statsmodels numpy scikit-image astropy bkcharts scipy imageio mkl-service matplotlib opencv seaborn mkl_random scikit-learn mkl_fft anaconda pywavelets h5py pytables py-opencv tifffile numba numpy-base nltk bokeh numexpr keras bottleneck matplotlib-base:   0%|          | 1/315 [00:06<32:56,  6.29s/it]
# Examining conflict for patsy pandas dask statsmodels numpy scikit-image astropy bkcharts scipy imageio mkl-service matplotlib opencv seaborn mkl_random scikit-learn mkl_fft anaconda pywavelets h5py pytables py-opencv tifffile numba numpy-base nltk bokeh numexpr keras bottleneck matplotlib-base:   1%|          | 2/315 [00:06<16:24,  3.15s/it]
# Examining conflict for patsy pandas dask statsmodels numpy scikit-image astropy bkcharts scipy imageio mkl-service matplotlib icc_rt hdf5 opencv seaborn mkl_random scikit-learn mkl_fft anaconda pywavelets h5py pytables py-opencv tifffile numba numpy-base nltk bokeh numexpr keras bottleneck matplotlib-base:   1%|          | 2/315 [00:15<16:24,  3.15s/it]
# Examining conflict for patsy pandas dask statsmodels numpy scikit-image astropy bkcharts scipy imageio mkl-service matplotlib icc_rt hdf5 opencv seaborn mkl_random scikit-learn mkl_fft anaconda pywavelets h5py pytables py-opencv tifffile numba numpy-base nltk bokeh numexpr keras bottleneck matplotlib-base:   1%|          | 3/315 [00:15<26:15,  5.05s/it]
# Examining conflict for patsy pandas certifi bleach zope.event distributed python-jsonrpc-server pyyaml bcrypt nbformat backports.functools_lru_cache pyopenssl pathtools ipython_genutils statsmodels jdcal qtpy backcall chardet jupyter_core anaconda-navigator mccabe astroid regex sympy more-itertools sphinxcontrib-websupport idna qtawesome cython qtconsole pluggy setuptools mkl_random toolz six ipykernel dask-core urllib3 clyent sqlalchemy pycurl olefile nest-asyncio jupyter_console entrypoints conda-build anaconda-client colorama pyrsistent isort sortedcontainers jupyterlab flask bokeh jinja2 cloudpickle keras sphinxcontrib-applehelp xlrd pylint testpath pyqt py path win_unicode_console dask jsonschema diff-match-patch conda-verify lazy-object-proxy qt pillow heapdict snowballstemmer numpy intervaltree _ipyw_jlab_nb_ext_conf requests python-dateutil bkcharts html5lib imageio pexpect pkginfo matplotlib brotlipy opencv singledispatch pytest multipledispatch cycler zope.interface openpyxl alabaster toml docutils sphinxcontrib-devhelp sphinxcontrib pycparser tifffile win_inet_pton pyodbc console_shortcut xlsxwriter numpy-base llvmlite jedi ruamel_yaml imagesize ply pywin32 future prompt-toolkit sortedcollections filelock unicodecsv matplotlib-base itsdangerous tblib tqdm navigator-updater jupyterlab_server prompt_toolkit nbclient pip ipython bitarray terminado iniconfig python-libarchive-c pydocstyle babel markupsafe scikit-image importlib_metadata spyder atomicwrites notebook python mistune pandocfilters ipywidgets anaconda-project comtypes pathlib2 path.py fastcache pyflakes ujson mkl-service zict mpmath pep8 cytoolz pyparsing pygments contextlib2 gevent et_xmlfile pywin32-ctypes argon2-cffi rtree prometheus_client fsspec pickleshare scikit-learn mkl_fft sphinxcontrib-serializinghtml h5py spyder-kernels lxml pytables decorator numba pycodestyle wrapt traitlets jupyter_client simplegeneric wcwidth boto python_abi numexpr backports conda sphinx partd py-lief tornado qdarkstyle click wheel sip locket sphinxcontrib-jsmath jupyterlab_pygments importlib-metadata xlwt backports.tempfile widgetsnbextension astropy pycosat watchdog networkx json5 scipy beautifulsoup4 werkzeug packaging attrs async_generator sphinxcontrib-htmlhelp wincertstore mock zope pytz paramiko seaborn soupsieve sqlite threadpoolctl backports.shutil_get_terminal_size joblib glob2 numpydoc rope pysocks menuinst xlwings nose cffi backports.weakref pynacl webencodings nbconvert autopep8 conda-package-handling pyzmq anaconda psutil powershell_shortcut msgpack-python sphinxcontrib-qthelp pywavelets defusedxml asn1crypto flake8 typing_extensions kiwisolver py-opencv argh pyreadline parso cryptography xmltodict python-language-server zipp nltk yapf send2trash jupyter pywinpty greenlet bottleneck keyring:   1%|          | 3/315 [00:25<26:15,  5.05s/it]
# Examining conflict for patsy pandas certifi bleach zope.event distributed python-jsonrpc-server pyyaml bcrypt nbformat backports.functools_lru_cache pyopenssl pathtools ipython_genutils statsmodels jdcal qtpy backcall chardet jupyter_core anaconda-navigator mccabe astroid regex sympy more-itertools sphinxcontrib-websupport idna qtawesome cython qtconsole pluggy setuptools mkl_random toolz six ipykernel dask-core urllib3 clyent sqlalchemy pycurl olefile nest-asyncio jupyter_console entrypoints conda-build anaconda-client colorama pyrsistent isort sortedcontainers jupyterlab flask bokeh jinja2 cloudpickle keras sphinxcontrib-applehelp xlrd pylint testpath pyqt py path win_unicode_console dask jsonschema diff-match-patch conda-verify lazy-object-proxy qt pillow heapdict snowballstemmer numpy intervaltree _ipyw_jlab_nb_ext_conf requests python-dateutil bkcharts html5lib imageio pexpect pkginfo matplotlib brotlipy opencv singledispatch pytest multipledispatch cycler zope.interface openpyxl alabaster toml docutils sphinxcontrib-devhelp sphinxcontrib pycparser tifffile win_inet_pton pyodbc console_shortcut xlsxwriter numpy-base llvmlite jedi ruamel_yaml imagesize ply pywin32 future prompt-toolkit sortedcollections filelock unicodecsv matplotlib-base itsdangerous tblib tqdm navigator-updater jupyterlab_server prompt_toolkit nbclient pip ipython bitarray terminado iniconfig python-libarchive-c pydocstyle babel markupsafe scikit-image importlib_metadata spyder atomicwrites notebook python mistune pandocfilters ipywidgets anaconda-project comtypes pathlib2 path.py fastcache pyflakes ujson mkl-service zict mpmath pep8 cytoolz pyparsing pygments contextlib2 gevent et_xmlfile pywin32-ctypes argon2-cffi rtree prometheus_client fsspec pickleshare scikit-learn mkl_fft sphinxcontrib-serializinghtml h5py spyder-kernels lxml pytables decorator numba pycodestyle wrapt traitlets jupyter_client simplegeneric wcwidth boto python_abi numexpr backports conda sphinx partd py-lief tornado qdarkstyle click wheel sip locket sphinxcontrib-jsmath jupyterlab_pygments importlib-metadata xlwt backports.tempfile widgetsnbextension astropy pycosat watchdog networkx json5 scipy beautifulsoup4 werkzeug packaging attrs async_generator sphinxcontrib-htmlhelp wincertstore mock zope pytz paramiko seaborn soupsieve sqlite threadpoolctl backports.shutil_get_terminal_size joblib glob2 numpydoc rope pysocks menuinst xlwings nose cffi backports.weakref pynacl webencodings nbconvert autopep8 conda-package-handling pyzmq anaconda psutil powershell_shortcut msgpack-python sphinxcontrib-qthelp pywavelets defusedxml asn1crypto flake8 typing_extensions kiwisolver py-opencv argh pyreadline parso cryptography xmltodict python-language-server zipp nltk yapf send2trash jupyter pywinpty greenlet bottleneck keyring:   1%|1         | 4/315 [00:25<34:04,  6.57s/it]
# Examining conflict for patsy pandas certifi bleach zope.event distributed python-jsonrpc-server pyyaml bcrypt nbformat backports.functools_lru_cache pyopenssl pathtools ipython_genutils statsmodels jdcal qtpy backcall chardet jupyter_core anaconda-navigator mccabe astroid regex sympy more-itertools sphinxcontrib-websupport idna qtawesome cython qtconsole pluggy setuptools mkl_random toolz six ipykernel dask-core urllib3 clyent sqlalchemy pycurl olefile nest-asyncio jupyter_console entrypoints conda-build anaconda-client colorama pyrsistent isort sortedcontainers jupyterlab flask bokeh jinja2 cloudpickle sphinxcontrib-applehelp xlrd pylint testpath pyqt py path win_unicode_console dask jsonschema diff-match-patch conda-verify lazy-object-proxy heapdict pillow snowballstemmer numpy intervaltree _ipyw_jlab_nb_ext_conf requests python-dateutil bkcharts html5lib imageio pexpect pkginfo matplotlib brotlipy singledispatch pytest multipledispatch cycler zope.interface openpyxl alabaster toml docutils sphinxcontrib-devhelp sphinxcontrib pycparser tifffile win_inet_pton pyodbc console_shortcut xlsxwriter numpy-base llvmlite jedi ruamel_yaml imagesize ply pywin32 future prompt-toolkit sortedcollections filelock unicodecsv matplotlib-base itsdangerous tblib tqdm navigator-updater jupyterlab_server prompt_toolkit nbclient pip ipython bitarray terminado iniconfig python-libarchive-c pydocstyle babel markupsafe scikit-image spyder atomicwrites notebook mistune pandocfilters ipywidgets anaconda-project comtypes pathlib2 path.py fastcache pyflakes ujson mkl-service zict mpmath pep8 cytoolz pyparsing pygments contextlib2 gevent et_xmlfile pywin32-ctypes argon2-cffi rtree prometheus_client fsspec pickleshare scikit-learn mkl_fft sphinxcontrib-serializinghtml h5py spyder-kernels lxml pytables decorator numba pycodestyle wrapt traitlets jupyter_client simplegeneric wcwidth boto numexpr backports conda sphinx partd py-lief tornado qdarkstyle click wheel sip locket sphinxcontrib-jsmath jupyterlab_pygments importlib-metadata xlwt backports.tempfile widgetsnbextension astropy pycosat watchdog networkx json5 scipy beautifulsoup4 werkzeug packaging attrs async_generator sphinxcontrib-htmlhelp wincertstore mock zope pytz paramiko seaborn soupsieve threadpoolctl backports.shutil_get_terminal_size joblib glob2 numpydoc rope pysocks menuinst xlwings nose cffi backports.weakref pynacl webencodings nbconvert autopep8 conda-package-handling pyzmq psutil pywavelets powershell_shortcut msgpack-python sphinxcontrib-qthelp defusedxml asn1crypto flake8 typing_extensions kiwisolver argh pyreadline parso cryptography xmltodict python-language-server zipp nltk yapf send2trash jupyter pywinpty greenlet bottleneck keyring:   1%|1         | 4/315 [00:41<34:04,  6.57s/it]
# Examining conflict for patsy pandas certifi bleach zope.event distributed python-jsonrpc-server pyyaml bcrypt nbformat backports.functools_lru_cache pyopenssl pathtools ipython_genutils statsmodels jdcal qtpy backcall chardet jupyter_core anaconda-navigator mccabe astroid regex sympy more-itertools sphinxcontrib-websupport idna qtawesome cython qtconsole pluggy setuptools mkl_random toolz six ipykernel dask-core urllib3 clyent sqlalchemy pycurl olefile nest-asyncio jupyter_console entrypoints conda-build anaconda-client colorama pyrsistent isort sortedcontainers jupyterlab flask bokeh jinja2 cloudpickle sphinxcontrib-applehelp xlrd pylint testpath pyqt py path win_unicode_console dask jsonschema diff-match-patch conda-verify lazy-object-proxy heapdict pillow snowballstemmer numpy intervaltree _ipyw_jlab_nb_ext_conf requests python-dateutil bkcharts html5lib imageio pexpect pkginfo matplotlib brotlipy singledispatch pytest multipledispatch cycler zope.interface openpyxl alabaster toml docutils sphinxcontrib-devhelp sphinxcontrib pycparser tifffile win_inet_pton pyodbc console_shortcut xlsxwriter numpy-base llvmlite jedi ruamel_yaml imagesize ply pywin32 future prompt-toolkit sortedcollections filelock unicodecsv matplotlib-base itsdangerous tblib tqdm navigator-updater jupyterlab_server prompt_toolkit nbclient pip ipython bitarray terminado iniconfig python-libarchive-c pydocstyle babel markupsafe scikit-image spyder atomicwrites notebook mistune pandocfilters ipywidgets anaconda-project comtypes pathlib2 path.py fastcache pyflakes ujson mkl-service zict mpmath pep8 cytoolz pyparsing pygments contextlib2 gevent et_xmlfile pywin32-ctypes argon2-cffi rtree prometheus_client fsspec pickleshare scikit-learn mkl_fft sphinxcontrib-serializinghtml h5py spyder-kernels lxml pytables decorator numba pycodestyle wrapt traitlets jupyter_client simplegeneric wcwidth boto numexpr backports conda sphinx partd py-lief tornado qdarkstyle click wheel sip locket sphinxcontrib-jsmath jupyterlab_pygments importlib-metadata xlwt backports.tempfile widgetsnbextension astropy pycosat watchdog networkx json5 scipy beautifulsoup4 werkzeug packaging attrs async_generator sphinxcontrib-htmlhelp wincertstore mock zope pytz paramiko seaborn soupsieve threadpoolctl backports.shutil_get_terminal_size joblib glob2 numpydoc rope pysocks menuinst xlwings nose cffi backports.weakref pynacl webencodings nbconvert autopep8 conda-package-handling pyzmq psutil pywavelets powershell_shortcut msgpack-python sphinxcontrib-qthelp defusedxml asn1crypto flake8 typing_extensions kiwisolver argh pyreadline parso cryptography xmltodict python-language-server zipp nltk yapf send2trash jupyter pywinpty greenlet bottleneck keyring:   2%|1         | 5/315 [00:41<47:47,  9.25s/it]
# ...
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> python-language-server[version='>=0.34.0,<1.0.0']
#
# Package liblief conflicts for:
# py-lief -> liblief[version='0.10.1|0.9.0|0.9.0|0.9.0',build='ha925a31_0|ha925a31_0|hd77b12b_1|ha925a31_3|ha925a31_2']
# anaconda==2020.11 -> liblief==0.10.1=ha925a31_0
# conda-build -> py-lief -> liblief[version='0.10.1|0.9.0|0.9.0|0.9.0',build='ha925a31_0|ha925a31_0|hd77b12b_1|ha925a31_3|ha925a31_2']
#
# Package scikit-learn conflicts for:
# anaconda==2020.11 -> scikit-learn==0.23.2[build='py38h47e9c7a_0|py37h47e9c7a_0']
# nltk -> scikit-learn
#
# Package pyyaml conflicts for:
# anaconda-client -> pyyaml[version='>=3.12']
# anaconda==2020.11 -> pyyaml==5.3.1[build='py38he774522_1|py37he774522_1']
# conda-verify -> pyyaml
# distributed -> pyyaml
# spyder -> watchdog[version='>=0.10.3,<2.0.0'] -> pyyaml[version='>=3.10']
# bokeh -> pyyaml[version='>=3.10']
# astropy -> pyyaml[version='>=3.13']
# anaconda==2020.11 -> anaconda-client==1.7.2=py37_0 -> pyyaml[version='>=3.10|>=3.12']
# keras -> pyyaml
# dask -> bokeh[version='>=1.0.0,!=2.0.0'] -> pyyaml[version='>=3.10']
# watchdog -> pyyaml[version='>=3.10']
# anaconda-navigator -> anaconda-client[version='>=1.6.14'] -> pyyaml[version='>=3.12']
# dask-core -> pyyaml
# conda-build -> pyyaml
# scikit-image -> dask-core[version='>=0.15.0'] -> pyyaml
# anaconda-navigator -> pyyaml[version='>=5.1']
# anaconda-project -> anaconda-client -> pyyaml[version='>=3.12']
#
# Package krb5 conflicts for:
# anaconda==2020.11 -> curl==7.71.1=h2a8f88b_1 -> krb5[version='>=1.18.2,<1.19.0a0']
# curl -> krb5[version='>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.18.2,<1.19.0a0']
# libcurl -> krb5[version='>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.18.2,<1.19.0a0']
# pycurl -> libcurl[version='>=7.71.1,<8.0a0'] -> krb5[version='>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.18.2,<1.19.0a0']
# anaconda==2020.11 -> krb5==1.18.2=hc04afaa_0
#
# Package qdarkstyle conflicts for:
# anaconda==2020.11 -> qdarkstyle==2.8.1=py_0
# spyder -> qdarkstyle[version='3.0.2.*|>=2.8,<3.0|>=2.8|>=2.7']
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> qdarkstyle[version='>=2.8']
#
# Package pyreadline conflicts for:
# anaconda==2020.11 -> h5py==2.10.0=py37h5e291fa_0 -> pyreadline
# anaconda==2020.11 -> pyreadline==2.1[build='py37_1|py38_1']
# h5py -> pyreadline
# keras -> h5py -> pyreadline
#
# Package tblib conflicts for:
# dask -> distributed[version='>=2021.4.0'] -> tblib[version='>=1.6.0']
# distributed -> tblib[version='>=1.6.0']
# anaconda==2020.11 -> distributed==2.30.1=py37haa95532_0 -> tblib[version='>=1.6.0']
# anaconda==2020.11 -> tblib==1.7.0=py_0
#
# Package contextvars conflicts for:
# dask -> distributed[version='>=2021.3.0'] -> contextvars
# distributed -> contextvars
#
# Package dask conflicts for:
# anaconda==2020.11 -> dask==2.30.0=py_0
# scikit-image -> dask[version='>=0.5']
#
# Package sphinxcontrib-htmlhelp conflicts for:
# anaconda==2020.11 -> sphinxcontrib-htmlhelp==1.0.3=py_0
# numpydoc -> sphinx -> sphinxcontrib-htmlhelp
# anaconda==2020.11 -> sphinx==3.2.1=py_0 -> sphinxcontrib-htmlhelp
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-htmlhelp
# sphinx -> sphinxcontrib-htmlhelp
#
# Package backports.weakref conflicts for:
# conda-verify -> backports.tempfile -> backports.weakref
# backports.tempfile -> backports.weakref
#
# Package paramiko conflicts for:
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> paramiko[version='>=2.4.0']
# spyder -> paramiko[version='>=2.4.0']
# anaconda==2020.11 -> paramiko==2.7.2=py_0
#
# Package testpath conflicts for:
# anaconda==2020.11 -> nbconvert==6.0.7=py37_0 -> testpath
# nbconvert -> testpath
# spyder -> nbconvert[version='>=4.0'] -> testpath
# jupyter -> nbconvert -> testpath
# anaconda==2020.11 -> testpath==0.4.4=py_0
# notebook -> nbconvert -> testpath
#
# Package pillow conflicts for:
# anaconda==2020.11 -> pillow==8.0.1[build='py37h4fa10fc_0|py38h4fa10fc_0']
# scikit-image -> pillow[version='>=2.1.0|>=4.3.0']
# dask -> bokeh[version='>=1.0.0,!=2.0.0'] -> pillow[version='>=4.0|>=7.1.0']
# anaconda==2020.11 -> bokeh==2.2.3=py37_0 -> pillow[version='>=4.3.0|>=6.2.0|>=7.1.0']
# matplotlib-base -> pillow[version='>=6.2.0']
# imageio -> pillow
# bokeh -> pillow[version='>=4.0|>=7.1.0']
# scikit-image -> imageio[version='>=2.3.0'] -> pillow[version='>=6.2.0']
# matplotlib -> matplotlib-base[version='>=3.3.4,<3.3.5.0a0'] -> pillow[version='>=6.2.0']
# anaconda-navigator -> pillow
#
# Package kiwisolver conflicts for:
# nltk -> matplotlib -> kiwisolver
# scikit-image -> matplotlib-base[version='>=2.0.0'] -> kiwisolver[version='>=1.0.1']
# anaconda==2020.11 -> kiwisolver==1.3.0[build='py37hd77b12b_0|py38hd77b12b_0']
# matplotlib -> kiwisolver
# astropy -> matplotlib[version='>=3.0'] -> kiwisolver
# bokeh -> matplotlib -> kiwisolver
# anaconda==2020.11 -> matplotlib-base==3.3.2=py37hba9282a_0 -> kiwisolver[version='>=1.0.1']
# matplotlib -> matplotlib-base[version='>=3.3.4,<3.3.5.0a0'] -> kiwisolver[version='>=1.0.1']
# matplotlib-base -> kiwisolver[version='>=1.0.1']
# seaborn -> matplotlib[version='>=2.1.2'] -> kiwisolver
#
# Package defusedxml conflicts for:
# notebook -> nbconvert -> defusedxml
# jupyter -> nbconvert -> defusedxml
# anaconda==2020.11 -> nbconvert==6.0.7=py37_0 -> defusedxml
# anaconda==2020.11 -> defusedxml==0.6.0=py_0
# nbconvert -> defusedxml
# spyder -> nbconvert[version='>=4.0'] -> defusedxml
#
# Package zope.event conflicts for:
# anaconda==2020.11 -> gevent==20.9.0=py37he774522_0 -> zope.event
# gevent -> zope.event
# anaconda==2020.11 -> zope.event==4.5.0[build='py37_0|py38_0']
#
# Package sphinxcontrib-qthelp conflicts for:
# anaconda==2020.11 -> sphinxcontrib-qthelp==1.0.3=py_0
# anaconda==2020.11 -> sphinx==3.2.1=py_0 -> sphinxcontrib-qthelp
# numpydoc -> sphinx -> sphinxcontrib-qthelp
# sphinx -> sphinxcontrib-qthelp
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-qthelp
#
# Package menuinst conflicts for:
# conda-build -> conda[version='>=4.5'] -> menuinst[version='>=1.4.11,<2']
# conda[version='>=4.10.1'] -> menuinst[version='>=1.4.11,<2']
# anaconda==2020.11 -> menuinst==1.4.16[build='py38he774522_1|py37he774522_1']
#
# Package snappy conflicts for:
# blosc -> snappy[version='>=1.1.7,<2.0a0|>=1.1.8,<2.0a0']
# tifffile -> imagecodecs[version='>=2021.3.31'] -> snappy[version='>=1.1.8,<2.0a0']
# pytables -> blosc[version='>=1.16.3,<2.0a0'] -> snappy[version='>=1.1.7,<2.0a0|>=1.1.8,<2.0a0']
#
# Package sphinxcontrib-serializinghtml conflicts for:
# sphinx -> sphinxcontrib-serializinghtml
# anaconda==2020.11 -> sphinxcontrib-serializinghtml==1.1.4=py_0
# numpydoc -> sphinx -> sphinxcontrib-serializinghtml
# anaconda==2020.11 -> sphinx==3.2.1=py_0 -> sphinxcontrib-serializinghtml
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-serializinghtml
#
# Package statsmodels conflicts for:
# seaborn -> statsmodels[version='>=0.5.0']
# anaconda==2020.11 -> statsmodels==0.12.0[build='py38he774522_0|py37he774522_0']
#
# Package libllvm9 conflicts for:
# numba -> llvmlite[version='>=0.33.0'] -> libllvm9
# llvmlite -> libllvm9
#
# Package twisted conflicts for:
# notebook -> prometheus_client -> twisted
# prometheus_client -> twisted
#
# Package networkx conflicts for:
# anaconda==2020.11 -> networkx==2.5=py_0
# anaconda==2020.11 -> scikit-image==0.17.2=py37h1e1f486_0 -> networkx[version='>=2.0']
# scikit-image -> networkx[version='>=1.8,<2.0|>=1.8|>=2.0']
#
# Package pynacl conflicts for:
# anaconda==2020.11 -> paramiko==2.7.2=py_0 -> pynacl[version='>=1.0.1']
# spyder -> paramiko[version='>=2.4.0'] -> pynacl[version='>=1.0.1']
# anaconda==2020.11 -> pynacl==1.4.0[build='py38h62dcd97_1|py37h62dcd97_1']
# paramiko -> pynacl[version='>=1.0.1']
#
# Package glob2 conflicts for:
# anaconda==2020.11 -> glob2==0.7=py_0
# conda-build -> glob2[version='>=0.6']
#
# Package jupyterlab_server conflicts for:
# anaconda==2020.11 -> jupyterlab_server==1.2.0=py_0
# _ipyw_jlab_nb_ext_conf -> jupyterlab -> jupyterlab_server[version='>=0.2.0,<0.3.0|>=1.0.0,<2.0.0|>=1.1.0,<2.0.0|>=1.1.5,<2.0.0|>=2.3,<3']
# jupyterlab -> jupyterlab_server[version='>=0.2.0,<0.3.0|>=1.0.0,<2.0.0|>=1.1.0,<2.0.0|>=1.1.5,<2.0.0|>=2.3,<3']
# anaconda==2020.11 -> jupyterlab==2.2.6=py_0 -> jupyterlab_server[version='>=1.1.0,<2.0.0']
#
# Package argh conflicts for:
# anaconda==2020.11 -> argh==0.26.2[build='py37_0|py38_0']
# anaconda==2020.11 -> watchdog==0.10.3=py37_0 -> argh[version='>=0.24.1']
# spyder -> watchdog[version='>=0.10.3,<2.0.0'] -> argh[version='>=0.24.1']
# watchdog -> argh[version='>=0.24.1']
#
# Package numpydoc conflicts for:
# jedi -> numpydoc
# anaconda==2020.11 -> numpydoc==1.1.0=pyhd3eb1b0_1
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> numpydoc[version='>=0.6.0']
# ipython -> jedi[version='>=0.10,<0.18'] -> numpydoc
# spyder -> numpydoc[version='>=0.6.0']
#
# Package libxslt conflicts for:
# lxml -> libxslt[version='>=1.1.32,<2.0a0|>=1.1.33,<2.0a0|>=1.1.34,<2.0a0']
# anaconda==2020.11 -> lxml==4.6.1=py37h1350720_0 -> libxslt[version='>=1.1.34,<2.0a0']
# anaconda==2020.11 -> libxslt==1.1.34=he774522_0
#
# Package pyasn1 conflicts for:
# spyder -> paramiko[version='>=2.4.0'] -> pyasn1[version='>=0.1.7']
# paramiko -> pyasn1[version='>=0.1.7']
# prometheus_client -> twisted -> pyasn1
#
# Package heapdict conflicts for:
# anaconda==2020.11 -> zict==2.0.0=py_0 -> heapdict
# zict -> heapdict
# anaconda==2020.11 -> heapdict==1.0.1=py_0
# distributed -> zict[version='>=0.1.3'] -> heapdict
#
# Package argon2-cffi conflicts for:
# jupyterlab_server -> notebook[version='>=4.2.0'] -> argon2-cffi
# jupyter -> notebook -> argon2-cffi
# anaconda==2020.11 -> notebook==6.1.4=py37_0 -> argon2-cffi
# widgetsnbextension -> notebook[version='>=4.4.1'] -> argon2-cffi
# notebook -> argon2-cffi
# anaconda==2020.11 -> argon2-cffi==20.1.0[build='py38he774522_1|py37he774522_1']
# jupyterlab -> notebook[version='>=4.3.1'] -> argon2-cffi
#
# Package werkzeug conflicts for:
# flask -> werkzeug[version='>=0.14|>=0.15|>=0.7,<1.0.0']
# anaconda==2020.11 -> flask==1.1.2=py_0 -> werkzeug[version='>=0.15']
# anaconda==2020.11 -> werkzeug==1.0.1=py_0
#
# Package sphinxcontrib conflicts for:
# anaconda==2020.11 -> sphinxcontrib-websupport==1.2.4=py_0 -> sphinxcontrib
# sphinxcontrib-websupport -> sphinxcontrib
# sphinx -> sphinxcontrib-websupport -> sphinxcontrib
# anaconda==2020.11 -> sphinxcontrib==1.0[build='py37_1|py38_1']
#
# Package zict conflicts for:
# anaconda==2020.11 -> distributed==2.30.1=py37haa95532_0 -> zict[version='>=0.1.3']
# dask -> distributed[version='>=2021.4.0'] -> zict[version='>=0.1.2|>=0.1.3']
# distributed -> zict[version='>=0.1.2|>=0.1.3']
# anaconda==2020.11 -> zict==2.0.0=py_0
#
# Package conda-package-handling conflicts for:
# conda-build -> conda-package-handling[version='>=1.1|>=1.3']
# conda-build -> conda[version='>=4.5'] -> conda-package-handling[version='>=1.0.4|>=1.3.0']
# conda[version='>=4.10.1'] -> conda-package-handling[version='>=1.3.0']
# conda-verify -> conda-package-handling[version='>=1.0.4|>=1.1']
#
# Package ptyprocess conflicts for:
# pexpect -> ptyprocess[version='>=0.5']
# spyder -> pexpect[version='>=4.4.0'] -> ptyprocess[version='>=0.5']
#
# Package msgpack-python conflicts for:
# anaconda==2020.11 -> distributed==2.30.1=py37haa95532_0 -> msgpack-python[version='>=0.6.0']
# pip -> cachecontrol -> msgpack-python
# anaconda==2020.11 -> msgpack-python==1.0.0[build='py37h74a9793_1|py38h74a9793_1']
# distributed -> msgpack-python[version='>=0.6.0']
# dask -> distributed[version='>=2021.4.0'] -> msgpack-python[version='>=0.6.0']
#
# Package pydocstyle conflicts for:
# python-language-server -> pydocstyle[version='>=2.0.0']
# anaconda==2020.11 -> python-language-server==0.35.1=py_0 -> pydocstyle[version='>=2.0.0']
# anaconda==2020.11 -> pydocstyle==5.1.1=py_0
# spyder -> python-language-server[version='>=0.36.2,<1.0.0'] -> pydocstyle[version='>=2.0.0']
#
# Package conda conflicts for:
# conda-build -> conda[version='>=4.3|>=4.5']
# anaconda-navigator -> conda-token -> conda[version='>=4.3']
#
# Package cryptography-vectors conflicts for:
# paramiko -> cryptography[version='>=1.5'] -> cryptography-vectors=2.3
# cryptography -> cryptography-vectors=2.3
# pyopenssl -> cryptography[version='>=2.2.1'] -> cryptography-vectors=2.3
# urllib3 -> cryptography[version='>=1.3.4'] -> cryptography-vectors=2.3
#
# Package win_unicode_console conflicts for:
# ipykernel -> ipython[version='>=5.0'] -> win_unicode_console[version='>=0.5']
# ipython -> win_unicode_console[version='>=0.5']
# anaconda==2020.11 -> win_unicode_console==0.5[build='py37_0|py38_0']
# ipywidgets -> ipython[version='>=4.0.0'] -> win_unicode_console[version='>=0.5']
# jupyterlab -> ipython -> win_unicode_console[version='>=0.5']
# jupyter_console -> ipython -> win_unicode_console[version='>=0.5']
#
# Package pylint conflicts for:
# anaconda==2020.11 -> pylint==2.6.0[build='py37_0|py38_0']
# python-language-server -> pylint[version='>=2.5.0']
# anaconda==2020.11 -> python-language-server==0.35.1=py_0 -> pylint[version='>=1.0']
# spyder -> python-language-server[version='>=0.36.2,<1.0.0'] -> pylint[version='>=2.5.0']
# spyder -> pylint[version='>=0.25|>=1.0']
#
# Package jupyter_console conflicts for:
# anaconda==2020.11 -> jupyter==1.0.0=py37_7 -> jupyter_console
# jupyter -> jupyter_console
# anaconda==2020.11 -> jupyter_console==6.2.0=py_0
#
# Package py-lief conflicts for:
# anaconda==2020.11 -> py-lief==0.10.1[build='py37ha925a31_0|py38ha925a31_0']
# conda-build -> py-lief
#
# Package bleach conflicts for:
# anaconda==2020.11 -> nbconvert==6.0.7=py37_0 -> bleach
# spyder -> nbconvert[version='>=4.0'] -> bleach
# anaconda==2020.11 -> bleach==3.2.1=py_0
# nbconvert -> bleach
# jupyter -> nbconvert -> bleach
# notebook -> nbconvert -> bleach
#
# Package pexpect conflicts for:
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> pexpect[version='>=4.4.0']
# anaconda==2020.11 -> pexpect==4.8.0[build='py37_1|py38_0']
# spyder -> pexpect[version='>=4.4.0']
#
# Package brotlipy conflicts for:
# anaconda==2020.11 -> urllib3==1.25.11=py_0 -> brotlipy[version='>=0.6.0']
# anaconda==2020.11 -> brotlipy==0.7.0[build='py38he774522_1000|py37he774522_1000']
# urllib3 -> brotlipy[version='>=0.6.0']
# requests -> urllib3[version='>=1.21.1,<1.27'] -> brotlipy[version='>=0.6.0']
#
# Package tifffile conflicts for:
# scikit-image -> tifffile[version='>=2019.7.26']
# anaconda==2020.11 -> tifffile==2020.10.1[build='py37h8c2d366_2|py38h8c2d366_2']
# anaconda==2020.11 -> scikit-image==0.17.2=py37h1e1f486_0 -> tifffile[version='>=2019.7.26']
#
# Package ipywidgets conflicts for:
# _ipyw_jlab_nb_ext_conf -> ipywidgets
# jupyter -> ipywidgets
# anaconda==2020.11 -> jupyter==1.0.0=py37_7 -> ipywidgets
# anaconda==2020.11 -> ipywidgets==7.5.1=py_1
#
# Package tbb4py conflicts for:
# numpy -> numpy-base==1.15.4=py27h2753ae9_0 -> tbb4py
# mkl_fft -> numpy-base[version='>=1.0.6,<2.0a0'] -> tbb4py
# mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> tbb4py
# numpy-base -> tbb4py
#
# Package h5py conflicts for:
# anaconda==2020.11 -> h5py==2.10.0[build='py37h5e291fa_0|py38h5e291fa_0']
# keras -> h5py
#
# Package imagecodecs conflicts for:
# tifffile -> imagecodecs[version='>=2021.3.31']
# scikit-image -> tifffile[version='>=2019.7.26'] -> imagecodecs[version='>=2021.3.31']
#
# Package rtree conflicts for:
# anaconda==2020.11 -> rtree==0.9.4[build='py37h21ff451_1|py38h21ff451_1']
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> rtree[version='>=0.8.3']
# spyder -> rtree[version='>=0.8.3']
#
# Package attrs conflicts for:
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> attrs[version='>=17.4.0']
# anaconda==2020.11 -> attrs==20.3.0=pyhd3eb1b0_0
# spyder -> jsonschema[version='>=3.2.0'] -> attrs[version='>=17.4.0']
# anaconda==2020.11 -> jsonschema==3.2.0=py_2 -> attrs[version='>=17.4.0']
# pytest -> attrs[version='>=17.2.0|>=17.4.0|>=19.2.0']
# prometheus_client -> twisted -> attrs[version='>=17.4.0']
# astropy -> pytest[version='<4'] -> attrs[version='>=17.2.0|>=17.4.0|>=19.2.0']
# jsonschema -> attrs[version='>=17.4.0']
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> attrs[version='>=17.4.0']
#
# Package hypothesis conflicts for:
# attrs -> hypothesis
# astropy -> pytest-astropy -> hypothesis
# pytest -> attrs[version='>=17.2.0'] -> hypothesis
#
# Package unittest2 conflicts for:
# h5py -> unittest2
# keras -> h5py -> unittest2
#
# Package black conflicts for:
# attrs -> hypothesis -> black[version='>=19.10b0']
# spyder -> pyls-black[version='>=0.4.6'] -> black
#
# Package pkginfo conflicts for:
# conda-build -> pkginfo
# anaconda==2020.11 -> pkginfo==1.6.1[build='py38haa95532_0|py37haa95532_0']

# %% [markdown]
# ## 4.3 Carregando imagens de treinamento e validação
#
# Selecione a melhor divisão entre dados de treinamento e validação. O número deverá ser representado em número fracionário, 5% equivale a 0.05, por exemplo.

# %%
## IMPLEMENTE
divisao_treino_validacao = 0.30

# %%
train_datagen = ImageDataGenerator(validation_split=divisao_treino_validacao)

train_generator = train_datagen.flow_from_directory(
    "raiox/train/",
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="training")
# Out:
# Found 3652 images belonging to 3 classes.

# %%
val_generator = train_datagen.flow_from_directory(
    "raiox/train/",
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="validation")
# Out:
# Found 1564 images belonging to 3 classes.

# %%
train_generator.class_indices, val_generator.class_indices
# Out:
# ({'NORMAL': 0, 'PNEUMONIA': 1}, {'NORMAL': 0, 'PNEUMONIA': 1})

# %% [markdown]
# ## 4.4 Modelos de transfer learning
#
# O Keras já possui classes especializadas para os seguintes modelos de deep-learning treinados com o conjunto de dados [ImageNet](http://www.image-net.org/):
#
# * Xception
# * VGG16
# * VGG19
# * ResNet50
# * InceptionV3
# * InceptionResNetV2
# * MobileNet
# * DenseNet
# * NASNet
# * MobileNetV2
#
# Mais detalhes, veja na [documentação do Keras](https://keras.io/applications/).

# %% [markdown]
# Para este estudo, vamos utilizar para avaliação as seguintes arquiteturas: RestNet50, VGG15 e VGG19.

# %% [markdown]
# ## 4.5 Indicadores de desempenho
#
# O Keras não possui os indicadores de desempenho como precisão, sensibilidade e pontuação f1 por padrão, portanto precisamos implementar externamente.

# %%
def recall_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_score(y_true, y_pred):
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ### 4.5.1 Arquitetura ResNet50

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do ResNet50? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %% [markdown]
# A técnica de transfer learning consiste de utilizar o mesmo modelo e treiná-lo para outas imagens. Por tal motivo, excluímos a última camada para modelar com as classes que definimos, ou seja, **controle**, **bacteriana** e **viral**.

# %% [markdown]
# Informe a quantidade de classes a serem classificadas.

# %%
## IMPLEMENTE

qtde_classes = 2

# %%
conv_base = ResNet50(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False
# Out:
# D:\ProgramData\Anaconda3\envs\visao-computacional\lib\site-packages\keras_applications\resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 145s 2us/step

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, None, None, 2 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, None, None, 2 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, None, None, 2 0           add_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           activation_49[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          262272      global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            258         dense_1[0][0]
# ==================================================================================================
# Total params: 23,850,242
# Trainable params: 262,530
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %% [markdown]
# O número de épocas define quantas vezes o modelo irá treinar e validar o erro, assim ajustando os pesos para melhor convergência.
# Escolha o número adequado de épocas para alcançarmos pelo menos **70% de precisão de validação**.

# %%
## IMPLEMENTE

qtde_epocas = 2

# %%
history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/2
# 5/5 [==============================] - 43s 9s/step - loss: 0.9277 - precision_score: 0.6500 - recall_score: 0.6500 - f1_score: 0.6500 - val_loss: 1.4474 - val_precision_score: 0.2438 - val_recall_score: 0.2438 - val_f1_score: 0.2437
# Epoch 2/2
# 5/5 [==============================] - 41s 8s/step - loss: 0.4677 - precision_score: 0.7125 - recall_score: 0.7125 - f1_score: 0.7125 - val_loss: 1.0457 - val_precision_score: 0.7500 - val_recall_score: 0.7500 - val_f1_score: 0.7500

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# ### 4.5.2 Arquitetura VGG16

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG16? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %%
conv_base = VGG16(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# ### 4.5.3 Arquitetura VGG19

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG19? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %%
conv_base = VGG19(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# ## 4.6 Compartivo de arquiteturas
#
# Preencha a tabela abaixo com os valores dos indicadores de performance apresentados.
#
# _O cálculo do F1-Score é dado por 2 * (Precisão * Sensibilidade) / (Precisão + Sensibilidade)._

# %% [markdown]
# | Modelo   | Precisão (*Precision*) | Sensibilidade (*Recall*) | F1-Score |
# |----------|----------|---------------|----------|
# | ResNet50 | XX %     | XX %          | XX %     |
# | VGG16    | XX %     | XX %          | XX %     |
# | VGG19    | XX %     | XX %          | XX %     |

# %% [markdown]
# ## 4.7 Conclusões
#
# Analise os resultados da tabela de indicadores do comparativo de arquiteturas e explique os principais motivos pelos quais cada modelo obteve cada resultado.

# %% [markdown]
# **Respota**:

# %% [markdown]
# ## 4.8 Abordagem Extra
#
# Considerando os outros classificadores, escolha outro que ainda não foi utilizado, implemente abaixo. Ao final compare os resultados e explique os resultados.
#
# _Não se esquece de utilizar as importações adequadas para cada modelo.
# A forma de implementação deve respeitar as mesmas condições como valor de split e quantidade de imagens para poder comparar os modelos._

# %%
#IMPLEMENTE

# %% [markdown]
# ### 4.8.1 Conclusões sobre a abordagem extra
#
# Como seu modelo performou em comparação com os demais modelos anteriores? Justifique sua resposta levando em consideração a arquitetura respectiva.

# %% [markdown]
# **Resposta**:
